# %% [markdown]
# # Analysis of Data Frames

# %%
# Import Libraries
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import matplotlib.dates as mdates
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import datetime as dt
from pandas import Timestamp
import time
from datetime import datetime, timedelta

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
os.listdir()
# Out:
# ['# Analysis of Data Frames.ipynb',
#  '.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  'Boston Marathon Analysis.pptx',
#  'Data',
#  'README.md']

# %%
os.getcwd()
# Out:
# 'D:\\Repositories\\BostonMarathon_RunningMagazine'

# %%
os.chdir('D:\\Repositories\\BostonMarathon_RunningMagazine\\Data')

# %%
os.listdir()
# Out:
# ['Barplot by Country.png',
#  'BoxPlot_2015_age_gender.png',
#  'marathon_results_2015.csv',
#  'marathon_results_2016.csv',
#  'marathon_results_2017.csv',
#  'MIRO Design of the Project.png',
#  'pro_elite_amateur.png',
#  'runners_2015.png',
#  'runners_2015_age_gender.png',
#  'Strategy_Top5_15_16_17.png',
#  'Strategy_Top5_2015-2016.png',
#  'Strategy_Top5_2015.png',
#  'Strategy_Top5_2016.png',
#  'Strategy_Top5_2017.png',
#  'Strategy_Winners15-16-17.png',
#  'Time_Age.png']

# %%
boston_2015 = pd.read_csv('marathon_results_2015.csv')

# %%
boston_2015
# Out:
#        Unnamed: 0    Bib                   Name  Age M/F           City State  \
# 0               0      3         Desisa, Lelisa   25   M           Ambo   NaN
# 1               1      4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN
# 2               2      8         Chebet, Wilson   29   M       Marakwet   NaN
# 3               3     11       Kipyego, Bernard   28   M        Eldoret   NaN
# 4               4     10          Korir, Wesley   32   M         Kitale   NaN
# ...           ...    ...                    ...  ...  ..            ...   ...
# 26593       26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL
# 26594       26594  31359    Emerson, Annette C.   61   F       Old Town    ME
# 26595       26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ
# 26596       26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA
# 26597       26597  25651        Reilly, William   62   M     Kew Garden    NY
#
#       Country Citizen Unnamed: 9  ...      25K      30K      35K      40K  \
# 0         ETH     NaN        NaN  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         ETH     NaN        NaN  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         KEN     NaN        NaN  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         KEN     NaN        NaN  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         KEN     NaN        NaN  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...     ...        ...  ...      ...      ...      ...      ...
# 26593     USA     NaN         MI  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     USA     NaN        NaN  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     USA     NaN        NaN  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     USA     NaN        NaN  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     USA     NaN         MI  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:56         -       2:09:17       1      1        1
# 1      0:04:58         -       2:09:48       2      2        2
# 2      0:04:59         -       2:10:22       3      3        3
# 3      0:05:00         -       2:10:47       4      4        4
# 4      0:05:00         -       2:10:49       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26593  0:17:31         -       7:38:56   26594  12015      269
# 26594  0:17:59         -       7:51:30   26595  12016      270
# 26595  0:18:18         -       7:59:33   26596  12017       91
# 26596  0:18:20         -       8:00:37   26597  14580     2055
# 26597  0:18:33         -       8:06:01   26598  14581      898
#
# [26598 rows x 25 columns]

# %%
boston_2016 = pd.read_csv('marathon_results_2016.csv')

# %%
boston_2017 = pd.read_csv('marathon_results_2017.csv')

# %%
boston_2015.loc[boston_2015['M/F']=='F'].head(20)
# Out:
#      Unnamed: 0   Bib                  Name  Age M/F             City State  \
# 30           30   F11      Rotich, Caroline   30   F        Nyahururu   NaN
# 31           31    F2          Dibaba, Mare   25   F             Shoa   NaN
# 33           33    F1        Deba, Buzunesh   27   F             Arsi   NaN
# 39           39   F10       Linden, Desiree   31   F  Rochester Mills    MI
# 43           43    F8        Cherop, Sharon   31   F         Marakwet   NaN
# 51           51    F9       Kilel, Caroline   34   F            Bomet   NaN
# 53           53    F3         Kebede, Aberu   28   F             Shoa   NaN
# 57           57    F6         Demise, Shure   19   F             Bore   NaN
# 61           61    F4     Flanagan, Shalane   33   F         Portland    OR
# 74           74   F16      Chepkirui, Joyce   26   F             Iten   NaN
# 77           77    F5    Duliba, Aleksandra   27   F            Minsk   NaN
# 145         145   F14           Nemec, Lisa   30   F           Zagreb   NaN
# 223         223   F18       Nelson, Adriana   35   F     Fort Collins    CO
# 235         235   F22         Amako, Megumi   24   F            Tokyo   NaN
# 303         303   F21     Dionne, Hilary K.   29   F      Charlestown    MA
# 329         329   F24     Philbrook, Lauren   27   F    State College    PA
# 472         472   F25  Phillips, Caitlin E.   32   F         New York    NY
# 497         497  1339         Zimmer, Lissa   23   F        Vancouver    BC
# 597         597   775       Misuraca, Katie   34   F       Gloucester    MA
# 608         608  1502    Duhon, Madeline E.   26   F       Somerville    MA
#
#     Country Citizen Unnamed: 9  ...      25K      30K      35K      40K  \
# 30      KEN     NaN        NaN  ...  1:26:08  1:43:24  2:00:50  2:17:30
# 31      ETH     NaN        NaN  ...  1:26:08  1:43:23  2:00:50  2:17:30
# 33      ETH     NaN        NaN  ...  1:26:09  1:43:24  2:00:50  2:17:30
# 39      USA     NaN        NaN  ...  1:26:08  1:43:23  2:00:49  2:17:51
# 43      KEN     NaN        NaN  ...  1:26:09  1:43:24  2:00:50  2:18:02
# 51      KEN     NaN        NaN  ...  1:26:08  1:43:23  2:00:50  2:18:11
# 53      ETH     NaN        NaN  ...  1:26:08  1:43:24  2:00:50  2:18:11
# 57      ETH     NaN        NaN  ...  1:26:08  1:43:24  2:00:50  2:18:21
# 61      USA     NaN        NaN  ...  1:26:09  1:43:34  2:01:35  2:19:45
# 74      KEN     NaN        NaN  ...  1:26:08  1:43:23  2:00:50  2:18:54
# 77      BLR     NaN        NaN  ...  1:26:09  1:44:15  2:03:06  2:21:22
# 145     CRO     NaN        NaN  ...  1:29:12  1:48:12  2:07:38  2:26:54
# 223     USA     NaN        NaN  ...  1:30:07  1:49:06  2:08:53  2:29:19
# 235     JPN     NaN        NaN  ...  1:32:02  1:51:22  2:11:19  2:30:47
# 303     USA     NaN        NaN  ...  1:31:48  1:51:08  2:11:15  2:31:22
# 329     USA     NaN        NaN  ...  1:35:28  1:54:36  2:14:09  2:33:03
# 472     USA     NaN        NaN  ...  1:36:52  1:56:26  2:16:27  2:35:49
# 497     CAN     USA        NaN  ...  1:38:14  1:57:59  2:17:41  2:36:37
# 597     USA     NaN        NaN  ...  1:39:08  1:58:47  2:18:38  2:37:46
# 608     USA     NaN        NaN  ...  1:35:33  1:55:28  2:16:11  2:36:55
#
#         Pace Proj Time Official Time Overall Gender Division
# 30   0:05:32         -       2:24:55      31      1        1
# 31   0:05:32         -       2:24:59      32      2        2
# 33   0:05:33         -       2:25:09      34      3        3
# 39   0:05:34         -       2:25:39      40      4        4
# 43   0:05:35         -       2:26:05      44      5        5
# 51   0:05:36         -       2:26:40      52      6        6
# 53   0:05:37         -       2:26:52      54      7        7
# 57   0:05:37         -       2:27:14      58      8        8
# 61   0:05:39         -       2:27:47      62      9        9
# 74   0:05:42         -       2:29:07      75     10       10
# 77   0:05:42         -       2:29:23      78     11       11
# 145  0:05:56         -       2:35:18     146     12       12
# 223  0:06:04         -       2:38:47     224     13       13
# 235  0:06:05         -       2:39:08     236     14       14
# 303  0:06:08         -       2:40:42     304     15       15
# 329  0:06:10         -       2:41:17     330     16       16
# 472  0:06:17         -       2:44:28     473     17       17
# 497  0:06:18         -       2:44:56     498     18       18
# 597  0:06:21         -       2:46:22     598     19       19
# 608  0:06:22         -       2:46:34     609     20       20
#
# [20 rows x 25 columns]

# %%
boston_2015.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
boston_2015['Unnamed: 0']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 26593    26593
# 26594    26594
# 26595    26595
# 26596    26596
# 26597    26597
# Name: Unnamed: 0, Length: 26598, dtype: int64

# %%
boston_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26598 entries, 0 to 26597
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26598 non-null  int64
#  1   Bib            26598 non-null  object
#  2   Name           26598 non-null  object
#  3   Age            26598 non-null  int64
#  4   M/F            26598 non-null  object
#  5   City           26598 non-null  object
#  6   State          24047 non-null  object
#  7   Country        26598 non-null  object
#  8   Citizen        1064 non-null   object
#  9   Unnamed: 9     67 non-null     object
#  10  5K             26598 non-null  object
#  11  10K            26598 non-null  object
#  12  15K            26598 non-null  object
#  13  20K            26598 non-null  object
#  14  Half           26598 non-null  object
#  15  25K            26598 non-null  object
#  16  30K            26598 non-null  object
#  17  35K            26598 non-null  object
#  18  40K            26598 non-null  object
#  19  Pace           26598 non-null  object
#  20  Proj Time      26598 non-null  object
#  21  Official Time  26598 non-null  object
#  22  Overall        26598 non-null  int64
#  23  Gender         26598 non-null  int64
#  24  Division       26598 non-null  int64
# dtypes: int64(5), object(20)
# memory usage: 5.1+ MB

# %%
boston_2015.shape
# Out:
# (26598, 25)

# %% [markdown]
# ## Drop unamed columns

# %% [markdown]
# ### Example of Function
# ```Python
#
# def unamed0(i):
#     """
#     This function will change:
#     1 - The name of the [Unamed: 0] columns Change it to  ['Ranking']
#     2- Chage the values of the ranking to start with 1 instead 0
#     """
#     if 'Unnamed: 0' in i.columns:
#         i.drop(['Unnamed: 0'], axis=1, inplace=True)
#         i['Ranking']=i.index+1
#     else:
#         i['Ranking']=i.index+1
#     return i
# ```

# %%
def unamed0(i):
    """
    This function will drop the colums called ['Unnamed: 0']
    """
    if 'Unnamed: 0' in i.columns:
        i.drop(['Unnamed: 0'], axis=1, inplace=True)
    else:
        pass
    return i

# %%
boston_2015 = unamed0(boston_2015)

# %%
boston_2016 = unamed0(boston_2016)

# %%
boston_2017 = unamed0(boston_2017)

# %%
def unamed9(i):
    """
    This function will drop the colums called ['Unnamed: 9']
    """
    if 'Unnamed: 9' in i.columns:
        i.drop(['Unnamed: 9'], axis=1, inplace=True)
    else:
        pass
    return i

# %%
boston_2015 = unamed9(boston_2015)

# %%
boston_2016 = unamed9(boston_2016)

# %%
boston_2017 = unamed9(boston_2017)

# %%
boston_2017
# Out:
#          Bib                      Name  Age M/F           City State Country  \
# 0         11           Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1         17               Rupp, Galen   30   M       Portland    OR     USA
# 2         23             Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3         21          Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4          9            Chebet, Wilson   31   M       Marakwet   NaN     KEN
# ...      ...                       ...  ...  ..            ...   ...     ...
# 26405  25166  Steinbach, Paula Eyvonne   61   F        Ontario    CA     USA
# 26406  25178        Avelino, Andrew R.   25   M   Fayetteville    NC     USA
# 26407  27086           Hantel, Johanna   57   F        Malvern    PA     USA
# 26408  25268              Reilly, Bill   64   M       New York    NY     USA
# 26409  25266             Rigsby, Scott   48   M     Alpharetta    GA     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:19  2:02:53
# 1         NaN  0:15:24  0:30:27  ...  1:16:59  1:33:01  1:48:19  2:03:14
# 2         NaN  0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:31  2:03:38
# 3         NaN  0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:58  2:04:35
# 4         NaN  0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:41  2:05:00
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26405     NaN  0:46:44  1:35:41  ...  4:12:06  5:03:08  5:55:18  6:46:57
# 26406     NaN  0:32:03  1:05:33  ...  3:50:19  4:50:01  5:53:48  6:54:21
# 26407     NaN  0:53:11  1:43:36  ...  4:15:21  5:06:37  6:00:33  6:54:38
# 26408     NaN  0:40:34  1:27:19  ...  4:06:10  5:07:09  6:06:07  6:56:08
# 26409     NaN  0:39:36  1:17:12  ...  4:27:14  5:37:13  6:39:07  7:41:23
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:57         -       2:09:37       1      1        1
# 1      0:04:58         -       2:09:58       2      2        2
# 2      0:04:59         -       2:10:28       3      3        3
# 3      0:05:03         -       2:12:08       4      4        4
# 4      0:05:04         -       2:12:35       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26405  0:16:24         -       7:09:39   26407  11972      344
# 26406  0:16:40         -       7:16:59   26408  14436     4774
# 26407  0:16:47         -       7:19:37   26409  11973      698
# 26408  0:16:49         -       7:20:44   26410  14437     1043
# 26409  0:18:15         -       7:58:14   26411  14438     2553
#
# [26410 rows x 23 columns]

# %% [markdown]
# # Winners in the three edition

# %%
#df2 = df2.append(df1[df1['Adj.Factor'] == 0])
winners = boston_2015[boston_2015['Overall']==1]
winners = winners.append(boston_2016[boston_2016['Overall']==1])
winners = winners.append(boston_2017[boston_2017['Overall']==1])

# %%
winners
# Out:
#   Bib                 Name  Age M/F         City State Country Citizen  \
# 0   3       Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 0   5  Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH     NaN
# 0  11      Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN
#
#         5K      10K  ...      30K      35K      40K     Pace Proj Time  \
# 0  0:14:43  0:29:43  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 0  0:15:47  0:31:20  ...  1:34:17  1:50:24  2:05:59  0:05:04   2:12:45
# 0  0:15:25  0:30:28  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
#
#   Official Time Overall Gender Division Unnamed: 8
# 0       2:09:17       1      1        1        NaN
# 0       2:12:45       1      1        1        NaN
# 0       2:09:37       1      1        1        NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# ## Reset index

# %%
winners = winners.reset_index()

# %%
winners.drop(['index'], axis=1, inplace=True)

# %%
winners
# Out:
#   Bib                 Name  Age M/F         City State Country Citizen  \
# 0   3       Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 1   5  Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH     NaN
# 2  11      Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN
#
#         5K      10K  ...      30K      35K      40K     Pace Proj Time  \
# 0  0:14:43  0:29:43  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1  0:15:47  0:31:20  ...  1:34:17  1:50:24  2:05:59  0:05:04   2:12:45
# 2  0:15:25  0:30:28  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
#
#   Official Time Overall Gender Division Unnamed: 8
# 0       2:09:17       1      1        1        NaN
# 1       2:12:45       1      1        1        NaN
# 2       2:09:37       1      1        1        NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# ## Add winner of the year

# %%
winners['Year'] = ['2015', '2016', '2017']

# %%
winners
# Out:
#   Bib                 Name  Age M/F         City State Country Citizen  \
# 0   3       Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 1   5  Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH     NaN
# 2  11      Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN
#
#         5K      10K  ...      35K      40K     Pace Proj Time Official Time  \
# 0  0:14:43  0:29:43  ...  1:47:59  2:02:39  0:04:56         -       2:09:17
# 1  0:15:47  0:31:20  ...  1:50:24  2:05:59  0:05:04   2:12:45       2:12:45
# 2  0:15:25  0:30:28  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
#
#   Overall Gender Division Unnamed: 8  Year
# 0       1      1        1        NaN  2015
# 1       1      1        1        NaN  2016
# 2       1      1        1        NaN  2017
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Remove Unnamed 8

# %%
winners.drop(['Unnamed: 8'], axis=1, inplace=True)

# %%
winners
# Out:
#   Bib                 Name  Age M/F         City State Country Citizen  \
# 0   3       Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 1   5  Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH     NaN
# 2  11      Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN
#
#         5K      10K  ...      30K      35K      40K     Pace Proj Time  \
# 0  0:14:43  0:29:43  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1  0:15:47  0:31:20  ...  1:34:17  1:50:24  2:05:59  0:05:04   2:12:45
# 2  0:15:25  0:30:28  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
#
#   Official Time Overall Gender Division  Year
# 0       2:09:17       1      1        1  2015
# 1       2:12:45       1      1        1  2016
# 2       2:09:37       1      1        1  2017
#
# [3 rows x 24 columns]

# %% [markdown]
# # Update winners Columns to make visualizations

# %%
winners_short = winners[['Name','5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official Time', 'Year']]

# %%
winners_short
# Out:
#                   Name       5K      10K      15K      20K     Half      25K  \
# 0       Desisa, Lelisa  0:14:43  0:29:43  0:44:57  1:00:29  1:04:02  1:16:07
# 1  Hayle, Lemi Berhanu  0:15:47  0:31:20  0:47:07  1:03:14  1:06:45  1:19:15
# 2      Kirui, Geoffrey  0:15:25  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59
#
#        30K      35K      40K Official Time  Year
# 0  1:32:00  1:47:59  2:02:39       2:09:17  2015
# 1  1:34:17  1:50:24  2:05:59       2:12:45  2016
# 2  1:33:01  1:48:19  2:02:53       2:09:37  2017

# %% [markdown]
# ## convert Time in Seconds

# %%
def seconds(j):
    """
    This Function will transform the time to seconds. 
    Input = Column Data Frame 00:00:==
    Output values in second 7800
    """
    a = [str(i).split(':') for i in j]
    b = [int(i[0])*3600+int(i[1])*60+int(i[2]) for i in a]
    return b

# %%
seconds(winners_short['Official Time'])
# Out:
# [7757, 7965, 7777]

# %%
winners_short
# Out:
#                   Name       5K      10K      15K      20K     Half      25K  \
# 0       Desisa, Lelisa  0:14:43  0:29:43  0:44:57  1:00:29  1:04:02  1:16:07
# 1  Hayle, Lemi Berhanu  0:15:47  0:31:20  0:47:07  1:03:14  1:06:45  1:19:15
# 2      Kirui, Geoffrey  0:15:25  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59
#
#        30K      35K      40K Official Time  Year
# 0  1:32:00  1:47:59  2:02:39       2:09:17  2015
# 1  1:34:17  1:50:24  2:05:59       2:12:45  2016
# 2  1:33:01  1:48:19  2:02:53       2:09:37  2017

# %% [markdown]
# ### Create a melt table for winners

# %%
winners_chart = winners_short.melt(id_vars=['Year','Name'])

# %%
winners_chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-466ec48b262d> in <module>
# ----> 1 winners_chart
#
# NameError: name 'winners_chart' is not defined

# %% [markdown]
# ## Total Time in Seconds

# %%
winners_seconds = winners_short.copy()

# %%
winners_seconds
# Out:
#                   Name       5K      10K      15K      20K     Half      25K  \
# 0       Desisa, Lelisa  0:14:43  0:29:43  0:44:57  1:00:29  1:04:02  1:16:07
# 1  Hayle, Lemi Berhanu  0:15:47  0:31:20  0:47:07  1:03:14  1:06:45  1:19:15
# 2      Kirui, Geoffrey  0:15:25  0:30:28  0:45:44  1:01:15  1:04:35  1:16:59
#
#        30K      35K      40K Official Time  Year
# 0  1:32:00  1:47:59  2:02:39       2:09:17  2015
# 1  1:34:17  1:50:24  2:05:59       2:12:45  2016
# 2  1:33:01  1:48:19  2:02:53       2:09:37  2017

# %%
winners_seconds['5K'] = seconds(winners_seconds['5K'])

# %%
winners_seconds['10K'] = seconds(winners_seconds['10K'])

# %%
winners_seconds['15K'] = seconds(winners_seconds['15K'])

# %%
winners_seconds['20K'] = seconds(winners_seconds['20K'])

# %%
winners_seconds['Half'] = seconds(winners_seconds['Half'])

# %%
winners_seconds['25K'] = seconds(winners_seconds['25K'])

# %%
winners_seconds['30K'] = seconds(winners_seconds['30K'])

# %%
winners_seconds['35K'] = seconds(winners_seconds['35K'])

# %%
winners_seconds['40K'] = seconds(winners_seconds['40K'])

# %%
winners_seconds['Official Time'] = seconds(winners_seconds['Official Time'])

# %%
winners_seconds
# Out:
#                   Name   5K   10K   15K   20K  Half   25K   30K   35K   40K  \
# 0       Desisa, Lelisa  883  1783  2697  3629  3842  4567  5520  6479  7359
# 1  Hayle, Lemi Berhanu  947  1880  2827  3794  4005  4755  5657  6624  7559
# 2      Kirui, Geoffrey  925  1828  2744  3675  3875  4619  5581  6499  7373
#
#    Official Time  Year
# 0           7757  2015
# 1           7965  2016
# 2           7777  2017

# %%
winners_seconds.loc['mean'] = winners_seconds.mean()

# %%
winners_seconds
# Out:
#                      Name          5K          10K     15K          20K  \
# 0          Desisa, Lelisa  883.000000  1783.000000  2697.0  3629.000000
# 1     Hayle, Lemi Berhanu  947.000000  1880.000000  2827.0  3794.000000
# 2         Kirui, Geoffrey  925.000000  1828.000000  2744.0  3675.000000
# mean                  NaN  918.333333  1830.333333  2756.0  3699.333333
#
#              Half     25K     30K     35K          40K  Official Time  \
# 0     3842.000000  4567.0  5520.0  6479.0  7359.000000         7757.0
# 1     4005.000000  4755.0  5657.0  6624.0  7559.000000         7965.0
# 2     3875.000000  4619.0  5581.0  6499.0  7373.000000         7777.0
# mean  3907.333333  4647.0  5586.0  6534.0  7430.333333         7833.0
#
#                Year
# 0              2015
# 1              2016
# 2              2017
# mean  67173387339.0

# %%
winners_seconds_melt = winners_seconds.melt(id_vars=['Year','Name'])
winners_seconds_melt.round()
# Out:
#              Year                 Name       variable   value
# 0            2015       Desisa, Lelisa             5K   883.0
# 1            2016  Hayle, Lemi Berhanu             5K   947.0
# 2            2017      Kirui, Geoffrey             5K   925.0
# 3   67173387339.0                  NaN             5K   918.0
# 4            2015       Desisa, Lelisa            10K  1783.0
# 5            2016  Hayle, Lemi Berhanu            10K  1880.0
# 6            2017      Kirui, Geoffrey            10K  1828.0
# 7   67173387339.0                  NaN            10K  1830.0
# 8            2015       Desisa, Lelisa            15K  2697.0
# 9            2016  Hayle, Lemi Berhanu            15K  2827.0
# 10           2017      Kirui, Geoffrey            15K  2744.0
# 11  67173387339.0                  NaN            15K  2756.0
# 12           2015       Desisa, Lelisa            20K  3629.0
# 13           2016  Hayle, Lemi Berhanu            20K  3794.0
# 14           2017      Kirui, Geoffrey            20K  3675.0
# 15  67173387339.0                  NaN            20K  3699.0
# 16           2015       Desisa, Lelisa           Half  3842.0
# 17           2016  Hayle, Lemi Berhanu           Half  4005.0
# 18           2017      Kirui, Geoffrey           Half  3875.0
# 19  67173387339.0                  NaN           Half  3907.0
# 20           2015       Desisa, Lelisa            25K  4567.0
# 21           2016  Hayle, Lemi Berhanu            25K  4755.0
# 22           2017      Kirui, Geoffrey            25K  4619.0
# 23  67173387339.0                  NaN            25K  4647.0
# 24           2015       Desisa, Lelisa            30K  5520.0
# 25           2016  Hayle, Lemi Berhanu            30K  5657.0
# 26           2017      Kirui, Geoffrey            30K  5581.0
# 27  67173387339.0                  NaN            30K  5586.0
# 28           2015       Desisa, Lelisa            35K  6479.0
# 29           2016  Hayle, Lemi Berhanu            35K  6624.0
# 30           2017      Kirui, Geoffrey            35K  6499.0
# 31  67173387339.0                  NaN            35K  6534.0
# 32           2015       Desisa, Lelisa            40K  7359.0
# 33           2016  Hayle, Lemi Berhanu            40K  7559.0
# 34           2017      Kirui, Geoffrey            40K  7373.0
# 35  67173387339.0                  NaN            40K  7430.0
# 36           2015       Desisa, Lelisa  Official Time  7757.0
# 37           2016  Hayle, Lemi Berhanu  Official Time  7965.0
# 38           2017      Kirui, Geoffrey  Official Time  7777.0
# 39  67173387339.0                  NaN  Official Time  7833.0

# %%
pace = winners_seconds.copy()

# %% [markdown]
# ## Time in Seconds every 5 K

# %%
def seconds5K(j):
    """ 
    This function will take the time each 5 kilometers and calculate the pace per kilometter
    Input = DataFrame with time each 5 km in seconds
    Output: DataFrame pace per kilomter.
    
    """
    seconds_to_minute  = 60
    df = j.copy()
    df = df[['Name','5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', 'Official Time']]
    df = df.rename(columns={'Official Time': '42K'})
    
    for i,k in enumerate(df.columns): 
        if i == 0:
            pass
        elif i==1:
            df[5] = ((df[k])/5)
        elif i == 2:
            df[10] = ((df[k]-df['5K'])/5)
        elif i == 3:
            df[15] = ((df[k]-df['10K'])/5)
        elif i == 4:
            df[20] = ((df[k]-df['15K'])/5)
        elif i == 5:
            df[25] = ((df[k]-df['20K'])/5)
        elif i == 6:
            df[30] = ((df[k]-df['25K'])/5)
        elif i == 7:
            df[35] = ((df[k]-df['30K'])/5)
        elif i == 8:
            df[40] = ((df[k]-df['35K'])/5)
        elif i == 9:
            df[42] = ((df[k]-df['40K'])/2)
    df = df.drop(['5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', '42K'], axis=1)
    return df

# %%
pace_seconds = seconds5K(pace)

# %%
pace_seconds_melt = pace_seconds.melt(id_vars=['Name'])

# %%
pace_seconds_melt = pace_seconds_melt.replace(np.nan, 'mean')

# %%
fig = px.line(pace_seconds_melt, y=pace_seconds_melt['value'], x=pace_seconds_melt['variable'], color='Name')

fig.show()
# Out:
# <div>                            <div id="49fd4fa2-8a0c-4804-9bed-6e201afc7591" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49fd4fa2-8a0c-4804-9bed-6e201afc7591")) {                    Plotly.newPlot(                        "49fd4fa2-8a0c-4804-9bed-6e201afc7591",                        [{"hovertemplate": "Name=Desisa, Lelisa<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Desisa, Lelisa", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Desisa, Lelisa", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.0, 182.8, 186.4, 187.6, 190.6, 191.8, 176.0, 199.0], "yaxis": "y"}, {"hovertemplate": "Name=Hayle, Lemi Berhanu<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Hayle, Lemi Berhanu", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Hayle, Lemi Berhanu", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.4, 186.6, 189.4, 193.4, 192.2, 180.4, 193.4, 187.0, 203.0], "yaxis": "y"}, {"hovertemplate": "Name=Kirui, Geoffrey<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Kirui, Geoffrey", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Kirui, Geoffrey", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [185.0, 180.6, 183.2, 186.2, 188.8, 192.4, 183.6, 174.8, 202.0], "yaxis": "y"}, {"hovertemplate": "Name=mean<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "mean", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "mean", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [183.66666666666669, 182.39999999999998, 185.13333333333335, 188.66666666666669, 189.5333333333333, 187.8, 189.6, 179.2666666666666, 201.33333333333348], "yaxis": "y"}],                        {"legend": {"title": {"text": "Name"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111 ...

# %% [markdown]
# ## Three winners Visualization

# %%
fig=plt.figure(figsize=(16,8))
strategy_winners = sns.lineplot(data=pace_seconds_melt, y='value', x='variable', hue='Name', lw=2.5, marker='o')
a = strategy_winners.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
a[6]='3.35'
strategy_winners.set_yticklabels(a);
plt.grid()
plt.title('Winners 2015 - 2016 - 2017')
plt.ylabel('Time')
plt.xlabel('Kilometers')
plt.savefig('Strategy_Winners15-16-17', dpi = 300);
plt.show()
# Out:
# <ipython-input-63-b629ce6544d7>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Time in Seconds every 5 K

# %%
def minutes5K(j):
    """ 
    This function will take the time each 5 kilometers and calculate the pace per kilometter
    Input = DataFrame with time each 5 km in seconds
    Output: DataFrame pace per kilomter.
    
    """
    seconds_to_minute  = 60
    df = j.copy()
    df = df[['Name','5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', 'Official Time']]
    df = df.rename(columns={'Official Time': '42K'})
    
    for i,k in enumerate(df.columns): 
        if i == 0:
            pass
        elif i==1:
            df[5] = ((df[k])/5)
            lst = []
            dct ={}
            for i in df[5]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[5] = lst
        elif i == 2:
            lst = []
            dct ={}
            df[10] = ((df[k]-df['5K'])/5)
            for i in df[10]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[10] = lst
        elif i == 3:
            df[15] = ((df[k]-df['10K'])/5)
            lst = []
            dct ={}
            for i in df[15]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[15] = lst
        elif i == 4:
            df[20] = ((df[k]-df['15K'])/5)
            lst = []
            dct ={}
            for i in df[20]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[20] = lst
        elif i == 5:
            df[25] = ((df[k]-df['20K'])/5)
            lst = []
            dct ={}
            for i in df[25]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[25] = lst
        elif i == 6:
            df[30] = ((df[k]-df['25K'])/5)
            lst = []
            dct ={}
            for i in df[30]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[30] = lst
        elif i == 7:
            df[35] = ((df[k]-df['30K'])/5)
            lst = []
            dct ={}
            for i in df[35]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[35] = lst
        elif i == 8:
            df[40] = ((df[k]-df['35K'])/5)
            lst = []
            dct ={}
            for i in df[40]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[40] = lst
        elif i == 9:
            df[42] = ((df[k]-df['40K'])/2)
            lst = []
            dct ={}
            for i in df[42]:
                ty_res = time.gmtime(int(i))
                res = time.strftime("%M:%S",ty_res)
                dct.update({i:res})
            lst = dct.values()
            lst = pd.Series(lst)
            df[42] = lst
    df = df.drop(['5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', '42K'], axis=1)
    return df

# %%
pace_minutes = minutes5K(pace)

# %%
pace_minutes
# Out:
#                      Name      5     10     15     20     25     30     35  \
# 0          Desisa, Lelisa  02:56  03:00  03:02  03:06  03:07  03:10  03:11
# 1     Hayle, Lemi Berhanu  03:09  03:06  03:09  03:13  03:12  03:00  03:13
# 2         Kirui, Geoffrey  03:05  03:00  03:03  03:06  03:08  03:12  03:03
# mean                  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          40     42
# 0     02:56  03:19
# 1     03:07  03:23
# 2     02:54  03:22
# mean    NaN    NaN

# %% [markdown]
# ## Try to change the Minutes to time format for better visualizations

# %%
pace_minutes
# Out:
#                      Name      5     10     15     20     25     30     35  \
# 0          Desisa, Lelisa  02:56  03:00  03:02  03:06  03:07  03:10  03:11
# 1     Hayle, Lemi Berhanu  03:09  03:06  03:09  03:13  03:12  03:00  03:13
# 2         Kirui, Geoffrey  03:05  03:00  03:03  03:06  03:08  03:12  03:03
# mean                  NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          40     42
# 0     02:56  03:19
# 1     03:07  03:23
# 2     02:54  03:22
# mean    NaN    NaN

# %%
def minutes5KDElta(j):
    """ 
    This function will take the time each 5 kilometers and calculate the pace per kilometter
    Input = DataFrame with time each 5 km in seconds
    Output: DataFrame pace per kilomter.
    
    """
    df = j.copy()
    
    for i,k in enumerate(df.columns): 
        if i == 0:
            pass
        elif i==1:
            df[5] = pd.to_timedelta('00:'+df[5])
        elif i == 2:
            df[10] = pd.to_timedelta('00:'+df[10])
        elif i == 3:
            df[15] = pd.to_timedelta('00:'+df[15])
        elif i == 4:
            df[20] = pd.to_timedelta('00:'+df[20])
        elif i == 5:
            df[25] = pd.to_timedelta('00:'+df[25])
        elif i == 6:
            df[30] = pd.to_timedelta('00:'+df[30])
        elif i == 7:
            df[35] = pd.to_timedelta('00:'+df[35])
        elif i == 8:
            df[40] = pd.to_timedelta('00:'+df[40])
        elif i == 9:
            df[42] = pd.to_timedelta('00:'+df[42])
    return df

# %%
pace_minutes_delta=minutes5KDElta(pace_minutes)

# %%
pace_minutes_delta
# Out:
#                      Name               5              10              15  \
# 0          Desisa, Lelisa 0 days 00:02:56 0 days 00:03:00 0 days 00:03:02
# 1     Hayle, Lemi Berhanu 0 days 00:03:09 0 days 00:03:06 0 days 00:03:09
# 2         Kirui, Geoffrey 0 days 00:03:05 0 days 00:03:00 0 days 00:03:03
# mean                  NaN             NaT             NaT             NaT
#
#                   20              25              30              35  \
# 0    0 days 00:03:06 0 days 00:03:07 0 days 00:03:10 0 days 00:03:11
# 1    0 days 00:03:13 0 days 00:03:12 0 days 00:03:00 0 days 00:03:13
# 2    0 days 00:03:06 0 days 00:03:08 0 days 00:03:12 0 days 00:03:03
# mean             NaT             NaT             NaT             NaT
#
#                   40              42
# 0    0 days 00:02:56 0 days 00:03:19
# 1    0 days 00:03:07 0 days 00:03:23
# 2    0 days 00:02:54 0 days 00:03:22
# mean             NaT             NaT

# %%
pace_minutes_delta_melt = pace_minutes_delta.melt(id_vars=['Name'])

# %%
pace_minutes_delta_melt
# Out:
#                    Name variable           value
# 0        Desisa, Lelisa        5 0 days 00:02:56
# 1   Hayle, Lemi Berhanu        5 0 days 00:03:09
# 2       Kirui, Geoffrey        5 0 days 00:03:05
# 3                   NaN        5             NaT
# 4        Desisa, Lelisa       10 0 days 00:03:00
# 5   Hayle, Lemi Berhanu       10 0 days 00:03:06
# 6       Kirui, Geoffrey       10 0 days 00:03:00
# 7                   NaN       10             NaT
# 8        Desisa, Lelisa       15 0 days 00:03:02
# 9   Hayle, Lemi Berhanu       15 0 days 00:03:09
# 10      Kirui, Geoffrey       15 0 days 00:03:03
# 11                  NaN       15             NaT
# 12       Desisa, Lelisa       20 0 days 00:03:06
# 13  Hayle, Lemi Berhanu       20 0 days 00:03:13
# 14      Kirui, Geoffrey       20 0 days 00:03:06
# 15                  NaN       20             NaT
# 16       Desisa, Lelisa       25 0 days 00:03:07
# 17  Hayle, Lemi Berhanu       25 0 days 00:03:12
# 18      Kirui, Geoffrey       25 0 days 00:03:08
# 19                  NaN       25             NaT
# 20       Desisa, Lelisa       30 0 days 00:03:10
# 21  Hayle, Lemi Berhanu       30 0 days 00:03:00
# 22      Kirui, Geoffrey       30 0 days 00:03:12
# 23                  NaN       30             NaT
# 24       Desisa, Lelisa       35 0 days 00:03:11
# 25  Hayle, Lemi Berhanu       35 0 days 00:03:13
# 26      Kirui, Geoffrey       35 0 days 00:03:03
# 27                  NaN       35             NaT
# 28       Desisa, Lelisa       40 0 days 00:02:56
# 29  Hayle, Lemi Berhanu       40 0 days 00:03:07
# 30      Kirui, Geoffrey       40 0 days 00:02:54
# 31                  NaN       40             NaT
# 32       Desisa, Lelisa       42 0 days 00:03:19
# 33  Hayle, Lemi Berhanu       42 0 days 00:03:23
# 34      Kirui, Geoffrey       42 0 days 00:03:22
# 35                  NaN       42             NaT

# %% [markdown]
# #  Top 10 Strategies - 2015

# %%
Winners_2015 = boston_2015.head(5)
Winners_2015
# Out:
#   Bib                   Name  Age M/F         City State Country Citizen  \
# 0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH     NaN
# 1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH     NaN
# 2   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN     NaN
# 3  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN     NaN
# 4  10          Korir, Wesley   32   M       Kitale   NaN     KEN     NaN
#
#         5K      10K  ...      25K      30K      35K      40K     Pace  \
# 0  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39  0:04:56
# 1  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42  0:04:58
# 2  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01  0:04:59
# 3  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47  0:05:00
# 4  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27  0:05:00
#
#   Proj Time Official Time Overall Gender Division
# 0         -       2:09:17       1      1        1
# 1         -       2:09:48       2      2        2
# 2         -       2:10:22       3      3        3
# 3         -       2:10:47       4      4        4
# 4         -       2:10:49       5      5        5
#
# [5 rows x 23 columns]

# %%
Winners_2015 = Winners_2015[['Name','5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official Time']]

# %%
Winners_2015['5K'] = seconds(Winners_2015['5K'])
Winners_2015['10K'] = seconds(Winners_2015['10K'])
Winners_2015['15K'] = seconds(Winners_2015['15K'])
Winners_2015['20K'] = seconds(Winners_2015['20K'])
Winners_2015['Half'] = seconds(Winners_2015['Half'])
Winners_2015['25K'] = seconds(Winners_2015['25K'])
Winners_2015['30K'] = seconds(Winners_2015['30K'])
Winners_2015['35K'] = seconds(Winners_2015['35K'])
Winners_2015['40K'] = seconds(Winners_2015['40K'])
Winners_2015['Official Time'] = seconds(Winners_2015['Official Time'])
# Out:
# <ipython-input-75-1aac56e796dc>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-75-1aac56e796dc>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Winners_2015
# Out:
#                     Name   5K   10K   15K   20K  Half   25K   30K   35K   40K  \
# 0         Desisa, Lelisa  883  1783  2697  3629  3842  4567  5520  6479  7359
# 1  Tsegay, Yemane Adhane  883  1783  2698  3628  3841  4567  5519  6479  7362
# 2         Chebet, Wilson  883  1783  2697  3629  3842  4567  5520  6479  7381
# 3       Kipyego, Bernard  883  1784  2701  3629  3842  4567  5520  6483  7427
# 4          Korir, Wesley  883  1784  2698  3628  3841  4567  5520  6479  7407
#
#    Official Time
# 0           7757
# 1           7788
# 2           7822
# 3           7847
# 4           7849

# %%
Winners_2015.describe().round()
# Out:
#           5K     10K     15K     20K    Half     25K     30K     35K     40K  \
# count    5.0     5.0     5.0     5.0     5.0     5.0     5.0     5.0     5.0
# mean   883.0  1783.0  2698.0  3629.0  3842.0  4567.0  5520.0  6480.0  7387.0
# std      0.0     1.0     2.0     1.0     1.0     0.0     0.0     2.0    29.0
# min    883.0  1783.0  2697.0  3628.0  3841.0  4567.0  5519.0  6479.0  7359.0
# 25%    883.0  1783.0  2697.0  3628.0  3841.0  4567.0  5520.0  6479.0  7362.0
# 50%    883.0  1783.0  2698.0  3629.0  3842.0  4567.0  5520.0  6479.0  7381.0
# 75%    883.0  1784.0  2698.0  3629.0  3842.0  4567.0  5520.0  6479.0  7407.0
# max    883.0  1784.0  2701.0  3629.0  3842.0  4567.0  5520.0  6483.0  7427.0
#
#        Official Time
# count            5.0
# mean          7813.0
# std             40.0
# min           7757.0
# 25%           7788.0
# 50%           7822.0
# 75%           7847.0
# max           7849.0

# %%
Winners_2015_sec= seconds5K(Winners_2015)

# %%
Winners_2015_sec_melt = Winners_2015_sec.melt(id_vars=['Name'])

# %%
fig=plt.figure(figsize=(18,8))
strategy_winners2015 = sns.lineplot(data=Winners_2015_sec_melt, y='value', x='variable', hue='Name', lw=2.5)
a = strategy_winners2015.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
a[6]='3.35'
strategy_winners2015.set_yticklabels(a);
plt.grid()
plt.title('Wineers 2015')
plt.ylabel('Time')
plt.xlabel('Kilometers')
plt.savefig('Strategy_Top5_2015', dpi = 300);
plt.show()
# Out:
# <ipython-input-80-a580f439cf09>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig = px.line(Winners_2015_sec_melt, y=Winners_2015_sec_melt['value'], x=Winners_2015_sec_melt['variable'], color='Name')

fig.show()
# Out:
# <div>                            <div id="7eeb8785-ea92-4a60-b34a-1ccf23da54bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eeb8785-ea92-4a60-b34a-1ccf23da54bd")) {                    Plotly.newPlot(                        "7eeb8785-ea92-4a60-b34a-1ccf23da54bd",                        [{"hovertemplate": "Name=Desisa, Lelisa<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Desisa, Lelisa", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Desisa, Lelisa", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.0, 182.8, 186.4, 187.6, 190.6, 191.8, 176.0, 199.0], "yaxis": "y"}, {"hovertemplate": "Name=Tsegay, Yemane Adhane<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Tsegay, Yemane Adhane", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Tsegay, Yemane Adhane", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.0, 183.0, 186.0, 187.8, 190.4, 192.0, 176.6, 213.0], "yaxis": "y"}, {"hovertemplate": "Name=Chebet, Wilson<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Chebet, Wilson", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Chebet, Wilson", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.0, 182.8, 186.4, 187.6, 190.6, 191.8, 180.4, 220.5], "yaxis": "y"}, {"hovertemplate": "Name=Kipyego, Bernard<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Kipyego, Bernard", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Kipyego, Bernard", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.2, 183.4, 185.6, 187.6, 190.6, 192.6, 188.8, 210.0], "yaxis": "y"}, {"hovertemplate": "Name=Korir, Wesley<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Korir, Wesley", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Korir, Wesley", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.2, 182.8, 186.0, 187.8, 190.6, 191.8, 185.6, 221.0], "yaxis": "y"}],                        {"legend": {"title": {"text": "Name"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222,  ...

# %% [markdown]
# #  Top 10 Strategies - 2016

# %%
Winners_2016 = boston_2016.head(5)
Winners_2016
# Out:
#   Bib                   Name  Age M/F         City State Country Citizen  \
# 0   5    Hayle, Lemi Berhanu   21   M  Addis Ababa   NaN     ETH     NaN
# 1   1         Desisa, Lelisa   26   M         Ambo   NaN     ETH     NaN
# 2   6  Tsegay, Yemane Adhane   31   M  Addis Ababa   NaN     ETH     NaN
# 3  11          Korir, Wesley   33   M       Kitale   NaN     KEN     NaN
# 4  14       Lonyangata, Paul   23   M      Eldoret   NaN     KEN     NaN
#
#   Unnamed: 8       5K  ...      25K      30K      35K      40K     Pace  \
# 0        NaN  0:15:47  ...  1:19:15  1:34:17  1:50:24  2:05:59  0:05:04
# 1        NaN  0:15:47  ...  1:19:15  1:34:17  1:50:24  2:05:59  0:05:06
# 2        NaN  0:15:46  ...  1:19:15  1:34:45  1:50:48  2:06:47  0:05:07
# 3        NaN  0:15:46  ...  1:19:16  1:34:45  1:50:48  2:06:47  0:05:07
# 4        NaN  0:15:46  ...  1:19:18  1:34:46  1:51:30  2:08:11  0:05:11
#
#   Proj Time Official Time Overall Gender Division
# 0   2:12:45       2:12:45       1      1        1
# 1   2:13:32       2:13:32       2      2        2
# 2   2:14:02       2:14:02       3      3        3
# 3   2:14:05       2:14:05       4      4        4
# 4   2:15:45       2:15:45       5      5        5
#
# [5 rows x 24 columns]

# %%
Winners_2016 = Winners_2016[['Name','5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official Time']]

# %%
Winners_2016['5K'] = seconds(Winners_2016['5K'])
Winners_2016['10K'] = seconds(Winners_2016['10K'])
Winners_2016['15K'] = seconds(Winners_2016['15K'])
Winners_2016['20K'] = seconds(Winners_2016['20K'])
Winners_2016['Half'] = seconds(Winners_2016['Half'])
Winners_2016['25K'] = seconds(Winners_2016['25K'])
Winners_2016['30K'] = seconds(Winners_2016['30K'])
Winners_2016['35K'] = seconds(Winners_2016['35K'])
Winners_2016['40K'] = seconds(Winners_2016['40K'])
Winners_2016['Official Time'] = seconds(Winners_2016['Official Time'])
# Out:
# <ipython-input-84-40a63c306c26>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-84-40a63c306c26>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Winners_2016
# Out:
#                     Name   5K   10K   15K   20K  Half   25K   30K   35K   40K  \
# 0    Hayle, Lemi Berhanu  947  1880  2827  3794  4005  4755  5657  6624  7559
# 1         Desisa, Lelisa  947  1881  2828  3794  4006  4755  5657  6624  7559
# 2  Tsegay, Yemane Adhane  946  1880  2827  3793  4004  4755  5685  6648  7607
# 3          Korir, Wesley  946  1881  2827  3794  4006  4756  5685  6648  7607
# 4       Lonyangata, Paul  946  1881  2828  3794  4006  4758  5686  6690  7691
#
#    Official Time
# 0           7965
# 1           8012
# 2           8042
# 3           8045
# 4           8145

# %%
Winners_2016_sec= seconds5K(Winners_2016)

# %%
Winners_2016_sec_melt = Winners_2016_sec.melt(id_vars=['Name'])

# %%
fig=plt.figure(figsize=(18,8))
strategy_winners2016 = sns.lineplot(data=Winners_2016_sec_melt, y='value', x='variable', hue='Name', lw=2)
a = strategy_winners2016.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
a[6]='3.35'
strategy_winners2016.set_yticklabels(a);
plt.grid()
plt.title('Winers 2016')
plt.ylabel('Time')
plt.xlabel('Kilometers')
plt.savefig('Strategy_Top5_2016', dpi = 300);
plt.show()
# Out:
# <ipython-input-88-146dabbd520a>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig = px.line(Winners_2016_sec_melt, y=Winners_2016_sec_melt['value'], x=Winners_2016_sec_melt['variable'], color='Name')

fig.show()
# Out:
# <div>                            <div id="5958f9c0-0418-40a6-a21a-b6114fe3f317" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5958f9c0-0418-40a6-a21a-b6114fe3f317")) {                    Plotly.newPlot(                        "5958f9c0-0418-40a6-a21a-b6114fe3f317",                        [{"hovertemplate": "Name=Hayle, Lemi Berhanu<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Hayle, Lemi Berhanu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Hayle, Lemi Berhanu", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.4, 186.6, 189.4, 193.4, 192.2, 180.4, 193.4, 187.0, 203.0], "yaxis": "y"}, {"hovertemplate": "Name=Desisa, Lelisa<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Desisa, Lelisa", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Desisa, Lelisa", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.4, 186.8, 189.4, 193.2, 192.2, 180.4, 193.4, 187.0, 226.5], "yaxis": "y"}, {"hovertemplate": "Name=Tsegay, Yemane Adhane<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Tsegay, Yemane Adhane", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Tsegay, Yemane Adhane", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.2, 186.8, 189.4, 193.2, 192.4, 186.0, 192.6, 191.8, 217.5], "yaxis": "y"}, {"hovertemplate": "Name=Korir, Wesley<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Korir, Wesley", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Korir, Wesley", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.2, 187.0, 189.2, 193.4, 192.4, 185.8, 192.6, 191.8, 219.0], "yaxis": "y"}, {"hovertemplate": "Name=Lonyangata, Paul<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "Lonyangata, Paul", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Lonyangata, Paul", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.2, 187.0, 189.4, 193.2, 192.8, 185.6, 200.8, 200.2, 227.0], "yaxis": "y"}],                        {"legend": {"title": {"text": "Name"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.222 ...

# %% [markdown]
# #  Top 10 Strategies - 2017

# %%
Winners_2017 = boston_2017.head(5)
Winners_2017
# Out:
#   Bib              Name  Age M/F           City State Country Citizen  \
# 0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1  17       Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
#
#         5K      10K  ...      25K      30K      35K      40K     Pace  \
# 0  0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:15:24  0:30:27  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# 0         -       2:09:37       1      1        1
# 1         -       2:09:58       2      2        2
# 2         -       2:10:28       3      3        3
# 3         -       2:12:08       4      4        4
# 4         -       2:12:35       5      5        5
#
# [5 rows x 23 columns]

# %%
Winners_2017 = Winners_2017[['Name','5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official Time']]

# %%
Winners_2017['5K'] = seconds(Winners_2017['5K'])
Winners_2017['10K'] = seconds(Winners_2017['10K'])
Winners_2017['15K'] = seconds(Winners_2017['15K'])
Winners_2017['20K'] = seconds(Winners_2017['20K'])
Winners_2017['Half'] = seconds(Winners_2017['Half'])
Winners_2017['25K'] = seconds(Winners_2017['25K'])
Winners_2017['30K'] = seconds(Winners_2017['30K'])
Winners_2017['35K'] = seconds(Winners_2017['35K'])
Winners_2017['40K'] = seconds(Winners_2017['40K'])
Winners_2017['Official Time'] = seconds(Winners_2017['Official Time'])
# Out:
# <ipython-input-92-51ff64d7df43>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-92-51ff64d7df43>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Winners_2017
# Out:
#                Name   5K   10K   15K   20K  Half   25K   30K   35K   40K  \
# 0   Kirui, Geoffrey  925  1828  2744  3675  3875  4619  5581  6499  7373
# 1       Rupp, Galen  924  1827  2744  3675  3875  4619  5581  6499  7394
# 2     Osako, Suguru  925  1829  2744  3676  3876  4620  5581  6511  7418
# 3  Biwott, Shadrack  925  1829  2744  3679  3885  4620  5581  6538  7475
# 4    Chebet, Wilson  925  1828  2744  3675  3875  4619  5581  6521  7500
#
#    Official Time
# 0           7777
# 1           7798
# 2           7828
# 3           7928
# 4           7955

# %%
Winners_2017_sec= seconds5K(Winners_2017)

# %%
Winners_2017_sec_melt = Winners_2017_sec.melt(id_vars=['Name'])

# %%
fig=plt.figure(figsize=(18,8))
strategy_winners2017 = sns.lineplot(data=Winners_2017_sec_melt, y='value', x='variable', hue='Name', lw=2)
a = strategy_winners2017.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
a[6]='3.35'
strategy_winners2017.set_yticklabels(a);
plt.grid()
plt.title('Wineers 2017')
plt.ylabel('Time')
plt.xlabel('Kilometers')
plt.savefig('Strategy_Top5_2017', dpi = 300);
plt.show()
# Out:
# <ipython-input-96-c272c04d2dce>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=True)
strategy_winners2015 = sns.lineplot(ax=axes[0], data=Winners_2015_sec_melt, y='value', x='variable', hue='Name', lw=2.5)
a = strategy_winners2015.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
a[6]='3.35'

axes[0].set_yticklabels(a);
axes[0].set_title('Top5 2015')
axes[0].set_ylabel('Time')
axes[0].set_xlabel('Kilometers')

strategy_winners2016 = sns.lineplot(ax=axes[1], data=Winners_2016_sec_melt, y='value', x='variable', hue='Name', lw=2)
b = axes[1].get_yticks().tolist()
b[1]= '2.90'
b[2]= '3.00'
b[3]= '3.10'
b[4]='3.20'
b[5]='3.25'
b[6]='3.35'
axes[1].set_yticklabels(b);
axes[1].set_title('Top5 2016')
axes[1].set_ylabel('Time')
axes[1].set_xlabel('Kilometers')

strategy_winners2017 = sns.lineplot(ax=axes[2], data=Winners_2017_sec_melt, y='value', x='variable', hue='Name', lw=2)
c = axes[2].get_yticks().tolist()
c[1]= '2.90'
c[2]= '3.00'
c[3]= '3.10'
c[4]='3.20'
c[5]='3.25'
c[6]='3.35'
axes[2].set_title('Top5 2017')
axes[2].set_yticklabels(c);
axes[1].set_ylabel('Time')
axes[1].set_xlabel('Kilometers')
plt.savefig('Strategy_Top5_15_16_17', dpi = 300);
plt.show()
# Out:
# <ipython-input-97-5de7440c6e09>:11: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# <ipython-input-97-5de7440c6e09>:24: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# <ipython-input-97-5de7440c6e09>:38: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Winenrs Three Years:

# %% [markdown]
# # Runners who participate in the Three events

# %%
boston_2015.head(20)
# Out:
#    Bib                   Name  Age M/F               City State Country  \
# 0    3         Desisa, Lelisa   25   M               Ambo   NaN     ETH
# 1    4  Tsegay, Yemane Adhane   30   M        Addis Ababa   NaN     ETH
# 2    8         Chebet, Wilson   29   M           Marakwet   NaN     KEN
# 3   11       Kipyego, Bernard   28   M            Eldoret   NaN     KEN
# 4   10          Korir, Wesley   32   M             Kitale   NaN     KEN
# 5    9   Chepkwony, Frankline   30   M           Koibatek   NaN     KEN
# 6   14     Ritzenhein, Dathan   32   M           Rockford    MI     USA
# 7    1        Keflezighi, Meb   39   M          San Diego    CA     USA
# 8    5           Tola, Tadese   27   M        Addis Ababa   NaN     ETH
# 9   16        Shafar, Vitaliy   33   M              Lutsk   NaN     UKR
# 10  22        Tegenkamp, Matt   33   M           Portland    OR     USA
# 11  19     Eggleston, Jeffrey   30   M            Boulder    CO     USA
# 12  15         April, Lusapho   32   M          Uitenhage   NaN     RSA
# 13  20    Arciniaga, Nicholas   31   M          Flagstaff    AZ     USA
# 14  76          Goffi, Danilo   42   M  Parabiago - Milan   NaN     ITA
# 15  28          Canaday, Sage   29   M            Boulder    CO     USA
# 16  54       Zyryanov, Sergey   30   M             Moscow   NaN     RUS
# 17  29          Chavez, Chris   28   M         Burlingame    CA     USA
# 18  27      Macpherson, Scott   28   M           Columbia    MO     USA
# 19  33  Zablocki, Christopher   26   M              Essex    CT     USA
#
#    Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0      NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1      NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2      NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3      NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4      NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# 5      NaN  0:14:44  0:29:45  ...  1:16:07  1:32:00  1:47:59  2:03:18
# 6      NaN  0:14:45  0:29:45  ...  1:16:05  1:31:59  1:48:06  2:04:05
# 7      NaN  0:14:44  0:29:44  ...  1:16:07  1:31:59  1:47:59  2:04:58
# 8      NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:48:00  2:04:39
# 9      NaN  0:15:14  0:30:34  ...  1:17:18  1:33:11  1:49:43  2:06:16
# 10     NaN  0:14:46  0:29:50  ...  1:17:08  1:33:12  1:49:52  2:06:55
# 11     NaN  0:15:14  0:30:34  ...  1:17:19  1:33:30  1:50:12  2:06:47
# 12     NaN  0:14:44  0:29:44  ...  1:16:07  1:32:00  1:48:07  2:06:50
# 13     NaN  0:14:44  0:29:44  ...  1:17:50  1:35:43  1:53:33  2:10:40
# 14     NaN  0:15:53  0:32:17  ...  1:21:17  1:38:02  1:54:55  2:11:25
# 15     NaN  0:16:08  0:32:19  ...  1:21:18  1:38:01  1:54:54  2:11:37
# 16     NaN  0:15:53  0:32:17  ...  1:21:17  1:38:02  1:54:57  2:11:37
# 17     NaN  0:15:57  0:32:21  ...  1:21:50  1:38:46  1:56:05  2:12:58
# 18     NaN  0:16:08  0:32:17  ...  1:20:55  1:37:41  1:54:45  2:12:23
# 19     NaN  0:16:08  0:32:20  ...  1:21:50  1:38:40  1:55:47  2:13:07
#
#        Pace Proj Time Official Time Overall Gender Division
# 0   0:04:56         -       2:09:17       1      1        1
# 1   0:04:58         -       2:09:48       2      2        2
# 2   0:04:59         -       2:10:22       3      3        3
# 3   0:05:00         -       2:10:47       4      4        4
# 4   0:05:00         -       2:10:49       5      5        5
# 5   0:05:00         -       2:10:52       6      6        6
# 6   0:05:01         -       2:11:20       7      7        7
# 7   0:05:04         -       2:12:42       8      8        8
# 8   0:05:06         -       2:13:35       9      9        9
# 9   0:05:07         -       2:13:52      10     10       10
# 10  0:05:07         -       2:13:52      11     11       11
# 11  0:05:08         -       2:14:17      12     12       12
# 12  0:05:13         -       2:16:25      13     13       13
# 13  0:05:16         -       2:18:02      14     14       14
# 14  0:05:18         -       2:18:44      15     15        1
# 15  0:05:19         -       2:19:12      16     16       15
# 16  0:05:19         -       2:19:17      17     17       16
# 17  0:05:21         -       2:20:04      18     18       17
# 18  0:05:22         -       2:20:25      19     19       18
# 19  0:05:22         -       2:20:35      20     20       19
#
# [20 rows x 23 columns]

# %%
boston_2016.head(20)
# Out:
#    Bib                   Name  Age M/F                  City State Country  \
# 0    5    Hayle, Lemi Berhanu   21   M           Addis Ababa   NaN     ETH
# 1    1         Desisa, Lelisa   26   M                  Ambo   NaN     ETH
# 2    6  Tsegay, Yemane Adhane   31   M           Addis Ababa   NaN     ETH
# 3   11          Korir, Wesley   33   M                Kitale   NaN     KEN
# 4   14       Lonyangata, Paul   23   M               Eldoret   NaN     KEN
# 5    3         Kitwara, Sammy   29   M               Eldoret   NaN     KEN
# 6    9      Chebogut, Stephen   31   M               Eldoret   NaN     KEN
# 7   17          Nageeye, Abdi   27   M              Nijmegen   NaN     NED
# 8    7           Feleke, Getu   29   M           Addis Ababa   NaN     ETH
# 9   43          Hine, Zachary   28   M                Dallas    TX     USA
# 10  16      Nyasango, Cutbert   33   M                Harare   NaN     ZIM
# 11   4      Mekonnen, Tsegaye   20   M           Addis Ababa   NaN     ETH
# 12  21           Burrell, Ian   31   M      Colorado Springs    CO     USA
# 13  15        Kiprop, Jackson   29   M             Kapchorwa   NaN     UGA
# 14  27         Okuti, Harbert   30   M             New Paltz    NY     USA
# 15  19      Da Silva, Solonei   34   M  Penapolis, Sao Paulo   NaN     BRA
# 16  79           Wells, Clint   40   M               Boulder    CO     USA
# 17  30          Kamijo, Norio   32   M                 Tokyo   NaN     JPN
# 18  23       Igarashi, Shingo   30   M                 Tokyo   NaN     JPN
# 19  12       Kipyego, Michael   32   M               Eldoret   NaN     KEN
#
#    Citizen Unnamed: 8       5K  ...      25K      30K      35K      40K  \
# 0      NaN        NaN  0:15:47  ...  1:19:15  1:34:17  1:50:24  2:05:59
# 1      NaN        NaN  0:15:47  ...  1:19:15  1:34:17  1:50:24  2:05:59
# 2      NaN        NaN  0:15:46  ...  1:19:15  1:34:45  1:50:48  2:06:47
# 3      NaN        NaN  0:15:46  ...  1:19:16  1:34:45  1:50:48  2:06:47
# 4      NaN        NaN  0:15:46  ...  1:19:18  1:34:46  1:51:30  2:08:11
# 5      NaN        NaN  0:15:46  ...  1:19:17  1:35:03  1:52:19  2:09:07
# 6      NaN        NaN  0:15:47  ...  1:19:26  1:34:45  1:50:49  2:08:12
# 7      NaN        NaN  0:15:47  ...  1:19:16  1:34:52  1:51:24  2:08:38
# 8      NaN        NaN  0:15:46  ...  1:19:17  1:35:39  1:53:52  2:10:57
# 9      NaN        NaN  0:16:03  ...  1:20:38  1:37:26  1:54:46  2:12:47
# 10     NaN        NaN  0:15:47  ...  1:19:17  1:35:09  1:53:10  2:11:48
# 11     NaN        NaN  0:15:46  ...  1:19:15  1:35:16  1:54:39  2:14:23
# 12     NaN        NaN  0:15:54  ...  1:21:45  1:39:24  1:57:02  2:14:39
# 13     NaN        NaN  0:15:46  ...  1:19:15  1:35:08  1:53:44  2:14:33
# 14     UGA        NaN  0:15:53  ...  1:22:16  1:39:45  1:57:52  2:16:22
# 15     NaN        NaN  0:15:46  ...  1:20:06  1:37:44  1:57:06  2:16:29
# 16     NaN        NaN  0:16:26  ...  1:23:42  1:41:18  1:59:16  2:16:51
# 17     NaN        NaN  0:15:47  ...  1:19:38  1:37:40  1:57:07  2:17:06
# 18     NaN        NaN  0:16:56  ...  1:23:20  1:41:32  2:00:15  2:18:19
# 19     NaN        NaN  0:15:47  ...  1:19:41  1:37:25  1:57:39  2:17:51
#
#        Pace Proj Time Official Time Overall Gender Division
# 0   0:05:04   2:12:45       2:12:45       1      1        1
# 1   0:05:06   2:13:32       2:13:32       2      2        2
# 2   0:05:07   2:14:02       2:14:02       3      3        3
# 3   0:05:07   2:14:05       2:14:05       4      4        4
# 4   0:05:11   2:15:45       2:15:45       5      5        5
# 5   0:05:13   2:16:43       2:16:43       6      6        6
# 6   0:05:14   2:16:52       2:16:52       7      7        7
# 7   0:05:16   2:18:05       2:18:05       8      8        8
# 8   0:05:18   2:18:46       2:18:46       9      9        9
# 9   0:05:25   2:21:37       2:21:37      10     10       10
# 10  0:05:26   2:22:02       2:22:02      11     11       11
# 11  0:05:26   2:22:21       2:22:21      12     12       12
# 12  0:05:26   2:22:22       2:22:22      13     13       13
# 13  0:05:32   2:24:44       2:24:44      14     14       14
# 14  0:05:32   2:24:46       2:24:46      15     15       15
# 15  0:05:32   2:24:54       2:24:54      16     16       16
# 16  0:05:32   2:24:55       2:24:55      17     17        1
# 17  0:05:33   2:25:31       2:25:31      18     18       17
# 18  0:05:36   2:26:24       2:26:24      19     19       18
# 19  0:05:37   2:27:02       2:27:02      20     20       19
#
# [20 rows x 24 columns]

# %%
boston_2017.head(20)
# Out:
#    Bib                Name  Age M/F              City State Country Citizen  \
# 0   11     Kirui, Geoffrey   24   M          Keringet   NaN     KEN     NaN
# 1   17         Rupp, Galen   30   M          Portland    OR     USA     NaN
# 2   23       Osako, Suguru   25   M      Machida-City   NaN     JPN     NaN
# 3   21    Biwott, Shadrack   32   M     Mammoth Lakes    CA     USA     NaN
# 4    9      Chebet, Wilson   31   M          Marakwet   NaN     KEN     NaN
# 5   15    Abdirahman, Abdi   40   M           Phoenix    AZ     USA     NaN
# 6   63  Maiyo, Augustus K.   33   M  Colorado Springs    CO     USA     NaN
# 7    7         Sefir, Dino   28   M       Addis Ababa   NaN     ETH     NaN
# 8   18      Puskedra, Luke   27   M            Eugene    OR     USA     NaN
# 9   20         Ward, Jared   28   M         Kaysville    UT     USA     NaN
# 10  22       Quigley, Sean   32   M         Braintree    MA     USA     NaN
# 11   6      Tsegay, Yemane   32   M       Addis Ababa   NaN     ETH     NaN
# 12  14     Keflezighi, Meb   41   M         San Diego    CA     USA     NaN
# 13  16   Nyasango, Cutbert   34   M            Harara   NaN     ZIM     NaN
# 14  10       Korir, Wesley   34   M            Kitale   NaN     KEN     NaN
# 15  35    Puzey, Thomas R.   32   M         Flagstaff    AZ     USA     NaN
# 16  76       Kisri, Rachid   41   M  Briarcliff Manor    NY     USA     MAR
# 17   3     Mutai, Emmanuel   32   M            Lessos   NaN     KEN     NaN
# 18  30     Ndhlovu, Pardon   29   M             Vilas    NC     USA     ZIM
# 19  31       Harvey, Brian   29   M            Boston    MA     USA     NaN
#
#          5K      10K  ...      25K      30K      35K      40K     Pace  \
# 0   0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1   0:15:24  0:30:27  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2   0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3   0:15:25  0:30:29  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4   0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
# 5   0:15:25  0:30:28  ...  1:16:59  1:33:01  1:48:52  2:05:21  0:05:04
# 6   0:15:25  0:30:29  ...  1:17:00  1:33:01  1:49:06  2:05:41  0:05:05
# 7   0:15:24  0:30:28  ...  1:18:36  1:34:52  1:51:11  2:07:09  0:05:08
# 8   0:15:24  0:30:29  ...  1:17:26  1:34:05  1:50:53  2:07:17  0:05:09
# 9   0:15:25  0:30:30  ...  1:17:17  1:33:49  1:50:44  2:07:54  0:05:11
# 10  0:15:25  0:30:31  ...  1:18:20  1:34:58  1:51:55  2:08:10  0:05:11
# 11  0:15:24  0:30:27  ...  1:17:30  1:34:33  1:52:00  2:08:57  0:05:14
# 12  0:15:24  0:30:27  ...  1:17:43  1:34:43  1:51:57  2:09:09  0:05:14
# 13  0:15:26  0:31:13  ...  1:19:54  1:36:39  1:53:55  2:10:20  0:05:16
# 14  0:15:24  0:30:28  ...  1:17:08  1:34:17  1:51:50  2:09:58  0:05:17
# 15  0:16:23  0:32:47  ...  1:22:17  1:38:51  1:55:17  2:11:14  0:05:17
# 16  0:15:24  0:30:29  ...  1:18:20  1:35:33  1:53:10  2:10:36  0:05:18
# 17  0:15:24  0:30:27  ...  1:16:59  1:33:24  1:51:32  2:10:44  0:05:20
# 18  0:15:40  0:31:21  ...  1:19:53  1:36:38  1:53:54  2:11:36  0:05:21
# 19  0:16:10  0:32:34  ...  1:21:45  1:38:34  1:55:48  2:12:51  0:05:22
#
#    Proj Time Official Time Overall Gender Division
# 0          -       2:09:37       1      1        1
# 1          -       2:09:58       2      2        2
# 2          -       2:10:28       3      3        3
# 3          -       2:12:08       4      4        4
# 4          -       2:12:35       5      5        5
# 5          -       2:12:45       6      6        1
# 6          -       2:13:16       7      7        6
# 7          -       2:14:26       8      8        7
# 8          -       2:14:45       9      9        8
# 9          -       2:15:28      10     10        9
# 10         -       2:15:34      11     11       10
# 11         -       2:16:47      12     12       11
# 12         -       2:17:00      13     13        2
# 13         -       2:17:40      14     14       12
# 14         -       2:18:14      15     15       13
# 15         -       2:18:20      16     16       14
# 16         -       2:18:32      17     17        3
# 17         -       2:19:33      18     18       15
# 18         -       2:20:12      19     19       16
# 19         -       2:20:18      20     20       17
#
# [20 rows x 23 columns]

# %% [markdown]
# ## Tsegay, Yemane

# %%
boston_2015.loc[boston_2015['Name'].str.contains('Yemane')]
# Out:
#   Bib                   Name  Age M/F         City State Country Citizen  \
# 1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH     NaN
#
#         5K      10K  ...      25K      30K      35K      40K     Pace  \
# 1  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42  0:04:58
#
#   Proj Time Official Time Overall Gender Division
# 1         -       2:09:48       2      2        2
#
# [1 rows x 23 columns]

# %%
boston_2016[boston_2016['Name'].str.contains('Yemane')]
# Out:
#   Bib                   Name  Age M/F         City State Country Citizen  \
# 2   6  Tsegay, Yemane Adhane   31   M  Addis Ababa   NaN     ETH     NaN
#
#   Unnamed: 8       5K  ...      25K      30K      35K      40K     Pace  \
# 2        NaN  0:15:46  ...  1:19:15  1:34:45  1:50:48  2:06:47  0:05:07
#
#   Proj Time Official Time Overall Gender Division
# 2   2:14:02       2:14:02       3      3        3
#
# [1 rows x 24 columns]

# %%
boston_2017[boston_2017['Name'].str.contains('Yemane')]
# Out:
#    Bib            Name  Age M/F         City State Country Citizen       5K  \
# 11   6  Tsegay, Yemane   32   M  Addis Ababa   NaN     ETH     NaN  0:15:24
#
#         10K  ...      25K      30K      35K      40K     Pace Proj Time  \
# 11  0:30:27  ...  1:17:30  1:34:33  1:52:00  2:08:57  0:05:14         -
#
#    Official Time Overall Gender Division
# 11       2:16:47      12     12       11
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Creating new DataFrame with Yemane

# %%
Yemane_boston = boston_2015.loc[boston_2015['Name'].str.contains('Yemane')]
Yemane_boston = Yemane_boston.append(boston_2016.loc[boston_2016['Name'].str.contains('Yemane')])
Yemane_boston = Yemane_boston.append(boston_2017.loc[boston_2017['Name'].str.contains('Yemane')])

# %%
Yemane_boston
# Out:
#    Bib                   Name  Age M/F         City State Country Citizen  \
# 1    4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH     NaN
# 2    6  Tsegay, Yemane Adhane   31   M  Addis Ababa   NaN     ETH     NaN
# 11   6         Tsegay, Yemane   32   M  Addis Ababa   NaN     ETH     NaN
#
#          5K      10K  ...      30K      35K      40K     Pace Proj Time  \
# 1   0:14:43  0:29:43  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2   0:15:46  0:31:20  ...  1:34:45  1:50:48  2:06:47  0:05:07   2:14:02
# 11  0:15:24  0:30:27  ...  1:34:33  1:52:00  2:08:57  0:05:14         -
#
#    Official Time Overall Gender Division Unnamed: 8
# 1        2:09:48       2      2        2        NaN
# 2        2:14:02       3      3        3        NaN
# 11       2:16:47      12     12       11        NaN
#
# [3 rows x 24 columns]

# %%
Yemane_boston.reset_index()
# Out:
#    index Bib                   Name  Age M/F         City State Country  \
# 0      1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 1      2   6  Tsegay, Yemane Adhane   31   M  Addis Ababa   NaN     ETH
# 2     11   6         Tsegay, Yemane   32   M  Addis Ababa   NaN     ETH
#
#   Citizen       5K  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN  0:14:43  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 1     NaN  0:15:46  ...  1:34:45  1:50:48  2:06:47  0:05:07   2:14:02
# 2     NaN  0:15:24  ...  1:34:33  1:52:00  2:08:57  0:05:14         -
#
#   Official Time Overall Gender Division Unnamed: 8
# 0       2:09:48       2      2        2        NaN
# 1       2:14:02       3      3        3        NaN
# 2       2:16:47      12     12       11        NaN
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Removing (['Unnamed: 8']

# %%
Yemane_boston.drop(['Unnamed: 8'], axis=1, inplace=True)

# %% [markdown]
# ## Addign the Year Column to difference every

# %%
Yemane_boston['Year'] = ['2015', '2016', '2017']

# %%
Yemane_boston = Yemane_boston[['Name','5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official Time']]

# %%
Yemane_boston['5K'] = seconds(Yemane_boston['5K'])
Yemane_boston['10K'] = seconds(Yemane_boston['10K'])
Yemane_boston['15K'] = seconds(Yemane_boston['15K'])
Yemane_boston['20K'] = seconds(Yemane_boston['20K'])
Yemane_boston['Half'] = seconds(Yemane_boston['Half'])
Yemane_boston['25K'] = seconds(Yemane_boston['25K'])
Yemane_boston['30K'] = seconds(Yemane_boston['30K'])
Yemane_boston['35K'] = seconds(Yemane_boston['35K'])
Yemane_boston['40K'] = seconds(Yemane_boston['40K'])
Yemane_boston['Official Time'] = seconds(Yemane_boston['Official Time'])
# Out:
# <ipython-input-110-d76425de33fb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-110-d76425de33fb>:10: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Yemane_boston_sec= seconds5K(Yemane_boston)

# %%
Yemane_boston_sec['Year'] = ['2015', '2016', '2017']

# %%
Yemane_boston_sec_melt = Yemane_boston_sec.melt(id_vars=['Name', 'Year'])

# %%
plt.clf()
fig=plt.figure(figsize=(18,6))
strategy_Yemane = sns.lineplot(data=Yemane_boston_sec_melt, y='value', x='variable', hue='Year', lw=2)
a = strategy_Yemane.get_yticks().tolist()
a[1]= '2.90'
a[2]= '3.00'
a[3]= '3.10'
a[4]='3.20'
a[5]='3.25'
strategy_winners.set_yticklabels(a);
plt.title('Tsegay, Yemane')
plt.ylabel('Time')
plt.xlabel('Kilometers')
plt.grid()
plt.show()
plt.close()
# Out:
# <ipython-input-114-ab355d4479a5>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig = px.line(Yemane_boston_sec_melt, y=Yemane_boston_sec_melt['value'], x=Yemane_boston_sec_melt['variable'], color='Year')

fig.show()
# Out:
# <div>                            <div id="f511fd9d-f483-447c-836c-dd04095b5a38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f511fd9d-f483-447c-836c-dd04095b5a38")) {                    Plotly.newPlot(                        "f511fd9d-f483-447c-836c-dd04095b5a38",                        [{"hovertemplate": "Year=2015<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "2015", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "2015", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [176.6, 180.0, 183.0, 186.0, 187.8, 190.4, 192.0, 176.6, 213.0], "yaxis": "y"}, {"hovertemplate": "Year=2016<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "2016", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "2016", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [189.2, 186.8, 189.4, 193.2, 192.4, 186.0, 192.6, 191.8, 217.5], "yaxis": "y"}, {"hovertemplate": "Year=2017<br>variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "2017", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "2017", "orientation": "v", "showlegend": true, "type": "scatter", "x": [5, 10, 15, 20, 25, 30, 35, 40, 42], "xaxis": "x", "y": [184.8, 180.6, 183.4, 186.2, 195.0, 204.6, 209.4, 203.4, 235.0], "yaxis": "y"}],                        {"legend": {"title": {"text": "Year"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c1 ...

# %% [markdown]
# ## Comparision between categories

# %%
boston_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26593     NaN  0:50:15  1:43:31  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     NaN  0:48:36  1:39:39  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     NaN  0:53:03  1:47:16  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     NaN  0:49:04  1:40:12  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     NaN  0:40:14  1:28:18  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:56         -       2:09:17       1      1        1
# 1      0:04:58         -       2:09:48       2      2        2
# 2      0:04:59         -       2:10:22       3      3        3
# 3      0:05:00         -       2:10:47       4      4        4
# 4      0:05:00         -       2:10:49       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26593  0:17:31         -       7:38:56   26594  12015      269
# 26594  0:17:59         -       7:51:30   26595  12016      270
# 26595  0:18:18         -       7:59:33   26596  12017       91
# 26596  0:18:20         -       8:00:37   26597  14580     2055
# 26597  0:18:33         -       8:06:01   26598  14581      898
#
# [26598 rows x 23 columns]

# %%
provsamateur_2015 =  boston_2015.copy()

# %%
provsamateur_2015.reset_index()
# Out:
#        index    Bib                   Name  Age M/F           City State  \
# 0          0      3         Desisa, Lelisa   25   M           Ambo   NaN
# 1          1      4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN
# 2          2      8         Chebet, Wilson   29   M       Marakwet   NaN
# 3          3     11       Kipyego, Bernard   28   M        Eldoret   NaN
# 4          4     10          Korir, Wesley   32   M         Kitale   NaN
# ...      ...    ...                    ...  ...  ..            ...   ...
# 26593  26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL
# 26594  26594  31359    Emerson, Annette C.   61   F       Old Town    ME
# 26595  26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ
# 26596  26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA
# 26597  26597  25651        Reilly, William   62   M     Kew Garden    NY
#
#       Country Citizen       5K  ...      25K      30K      35K      40K  \
# 0         ETH     NaN  0:14:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         ETH     NaN  0:14:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         KEN     NaN  0:14:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         KEN     NaN  0:14:43  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         KEN     NaN  0:14:43  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...     ...      ...  ...      ...      ...      ...      ...
# 26593     USA     NaN  0:50:15  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     USA     NaN  0:48:36  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     USA     NaN  0:53:03  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     USA     NaN  0:49:04  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     USA     NaN  0:40:14  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:56         -       2:09:17       1      1        1
# 1      0:04:58         -       2:09:48       2      2        2
# 2      0:04:59         -       2:10:22       3      3        3
# 3      0:05:00         -       2:10:47       4      4        4
# 4      0:05:00         -       2:10:49       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26593  0:17:31         -       7:38:56   26594  12015      269
# 26594  0:17:59         -       7:51:30   26595  12016      270
# 26595  0:18:18         -       7:59:33   26596  12017       91
# 26596  0:18:20         -       8:00:37   26597  14580     2055
# 26597  0:18:33         -       8:06:01   26598  14581      898
#
# [26598 rows x 24 columns]

# %%
provsamateur_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26593     NaN  0:50:15  1:43:31  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     NaN  0:48:36  1:39:39  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     NaN  0:53:03  1:47:16  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     NaN  0:49:04  1:40:12  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     NaN  0:40:14  1:28:18  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:56         -       2:09:17       1      1        1
# 1      0:04:58         -       2:09:48       2      2        2
# 2      0:04:59         -       2:10:22       3      3        3
# 3      0:05:00         -       2:10:47       4      4        4
# 4      0:05:00         -       2:10:49       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26593  0:17:31         -       7:38:56   26594  12015      269
# 26594  0:17:59         -       7:51:30   26595  12016      270
# 26595  0:18:18         -       7:59:33   26596  12017       91
# 26596  0:18:20         -       8:00:37   26597  14580     2055
# 26597  0:18:33         -       8:06:01   26598  14581      898
#
# [26598 rows x 23 columns]

# %%
provsamateur_2015['5K'] = seconds(provsamateur_2015['5K'])
provsamateur_2015['10K'] = seconds(provsamateur_2015['10K'])
provsamateur_2015['15K'] = seconds(provsamateur_2015['15K'])
provsamateur_2015['20K'] = seconds(provsamateur_2015['20K'])
provsamateur_2015['Half'] = seconds(provsamateur_2015['Half'])
provsamateur_2015['25K'] = seconds(provsamateur_2015['25K'])
provsamateur_2015['30K'] = seconds(provsamateur_2015['30K'])
provsamateur_2015['35K'] = seconds(provsamateur_2015['35K'])
provsamateur_2015['40K'] = seconds(provsamateur_2015['40K'])
provsamateur_2015['Official Time'] = seconds(provsamateur_2015['Official Time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-58057c4c58ea> in <module>
# ----> 1 provsamateur_2015['5K'] = seconds(provsamateur_2015['5K'])
#       2 provsamateur_2015['10K'] = seconds(provsamateur_2015['10K'])
#       3 provsamateur_2015['15K'] = seconds(provsamateur_2015['15K'])
#       4 provsamateur_2015['20K'] = seconds(provsamateur_2015['20K'])
#       5 provsamateur_2015['Half'] = seconds(provsamateur_2015['Half'])
#
# <ipython-input-36-5a17c16d9d73> in seconds(j)
#       6     """
#       7     a = [str(i).split(':') for i in j]
# ----> 8     b = [int(i[0])*3600+int(i[1])*60+int(i[2]) for i in a]
#       9     return b
#      10
#
# <ipython-input-36-5a17c16d9d73> in <listcomp>(.0)
#       6     """
#       7     a = [str(i).split(':') for i in j]
# ----> 8     b = [int(i[0])*3600+int(i[1])*60+int(i[2]) for i in a]
#       9     return b
#      10
#
# ValueError: invalid literal for int() with base 10: '-'

# %% [markdown]
# ## There are 300 Rows with missin values as '-'

# %%
mask = np.column_stack([provsamateur_2015[col].str.contains('-', na=False) for col in provsamateur_2015.columns[8:18]])
provsamateur_2015.loc[mask.any(axis=1)]
# Out:
#          Bib                        Name  Age M/F  \
# 510     1119  Barrera Munoz, Ruben Dario   41   M
# 1221     311      Hammersmith, Matthew D   27   M
# 2021    2936     Villarreal, Marín G Sr.   30   M
# 2327    4803              Olsen, Lars R.   32   M
# 2787    5643                Curran, Phil   41   M
# ...      ...                         ...  ...  ..
# 26546  26837        Chamberlain, Kira H.   36   F
# 26557  26650             Macon, Laurence   70   M
# 26559  24014                 Wang, Genqi   65   M
# 26561  26176            Teel, Marilyn S.   54   F
# 26578  21042         Corcoran, Heather L   45   F
#
#                                  City State Country Citizen       5K      10K  \
# 510    Tlalnepantla, Estado De Mexico   NaN     MEX     NaN  0:18:40  0:37:32
# 1221                       Greenville    SC     USA     NaN  0:17:49  0:35:28
# 2021                               Df   NaN     MEX     NaN  0:19:55  0:39:49
# 2327                     Copenhagen N   NaN     DEN     NaN        -  0:42:00
# 2787                          Seattle    WA     USA     NaN  0:21:52  0:42:56
# ...                               ...   ...     ...     ...      ...      ...
# 26546                         Orlando    FL     USA     NaN        -  1:14:59
# 26557                     San Antonio    TX     USA     NaN        -  1:19:53
# 26559                         Beijing   NaN     CHN     NaN  0:28:18  1:06:09
# 26561                           Ocala    FL     USA     NaN  0:34:20  1:11:38
# 26578                   Saint Charles    IL     USA     NaN  0:25:09  0:49:38
#
#        ...      25K      30K      35K      40K     Pace Proj Time  \
# 510    ...        -  1:55:27  2:16:08  2:36:13  0:06:18         -
# 1221   ...  1:29:06  1:47:59  2:14:39        -  0:06:36         -
# 2021   ...  1:41:28  2:03:15  2:25:32        -  0:06:47         -
# 2327   ...  1:45:10  2:06:55  2:28:56  2:49:46  0:06:50         -
# 2787   ...  1:45:11  2:07:01  2:29:11        -  0:06:54         -
# ...    ...      ...      ...      ...      ...      ...       ...
# 26546  ...  3:20:43  4:04:46  4:51:33  5:41:12  0:13:52         -
# 26557  ...  3:27:27  4:13:19  4:57:59  5:43:59  0:13:56         -
# 26559  ...  3:16:51  4:03:55  4:50:43        -  0:13:57         -
# 26561  ...  3:21:23  4:07:14  4:54:56        -  0:13:58         -
# 26578  ...  2:22:13  3:03:23        -  5:54:25  0:14:13         -
#
#       Official Time Overall Gender Division
# 510         2:45:03     511    493       34
# 1221        2:52:38    1222   1167      957
# 2021        2:57:36    2022   1915     1471
# 2327        2:58:48    2328   2201     1655
# 2787        3:00:41    2788   2632      393
# ...             ...     ...    ...      ...
# 26546       6:03:29   26547  11994     5995
# 26557       6:05:18   26558  14559      120
# 26559       6:05:29   26560  14560      402
# 26561       6:05:57   26562  12001     1204
# 26578       6:12:28   26579  12010     1831
#
# [300 rows x 23 columns]

# %% [markdown]
# ## To detect where is the difference between Pros and Amateurs I just need one colums who is not missing.  Official Time

# %%
provsamateur_2015['Official Time'] = seconds(provsamateur_2015['Official Time'])

# %%
provsamateur_2015.rename(columns={'Official Time':'Official_Time'},inplace=True)

# %%
provsamateur_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26593     NaN  0:50:15  1:43:31  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     NaN  0:48:36  1:39:39  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     NaN  0:53:03  1:47:16  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     NaN  0:49:04  1:40:12  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     NaN  0:40:14  1:28:18  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official_Time Overall Gender  Division
# 0      0:04:56         -          7757       1      1         1
# 1      0:04:58         -          7788       2      2         2
# 2      0:04:59         -          7822       3      3         3
# 3      0:05:00         -          7847       4      4         4
# 4      0:05:00         -          7849       5      5         5
# ...        ...       ...           ...     ...    ...       ...
# 26593  0:17:31         -         27536   26594  12015       269
# 26594  0:17:59         -         28290   26595  12016       270
# 26595  0:18:18         -         28773   26596  12017        91
# 26596  0:18:20         -         28837   26597  14580      2055
# 26597  0:18:33         -         29161   26598  14581       898
#
# [26598 rows x 23 columns]

# %%
fig = px.box(provsamateur_2015, x="Official_Time")
fig.show()
# Out:
# <div>                            <div id="d0a609f5-b05f-4e8e-83fd-e6edc33f399c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0a609f5-b05f-4e8e-83fd-e6edc33f399c")) {                    Plotly.newPlot(                        "d0a609f5-b05f-4e8e-83fd-e6edc33f399c",                        [{"alignmentgroup": "True", "hovertemplate": "Official_Time=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "h", "showlegend": false, "type": "box", "x": [7757, 7788, 7822, 7847, 7849, 7852, 7880, 7962, 8015, 8032, 8032, 8057, 8185, 8282, 8324, 8352, 8357, 8404, 8425, 8435, 8442, 8470, 8476, 8518, 8525, 8550, 8601, 8677, 8684, 8689, 8695, 8699, 8708, 8709, 8710, 8710, 8714, 8728, 8731, 8739, 8747, 8747, 8758, 8765, 8769, 8775, 8784, 8789, 8795, 8796, 8798, 8800, 8801, 8812, 8821, 8828, 8830, 8834, 8836, 8840, 8857, 8867, 8869, 8873, 8874, 8877, 8890, 8894, 8897, 8898, 8903, 8909, 8913, 8924, 8947, 8956, 8960, 8963, 8967, 8977, 8978, 8982, 8985, 8989, 9003, 9015, 9017, 9019, 9028, 9029, 9068, 9078, 9083, 9094, 9098, 9117, 9119, 9121, 9122, 9125, 9126, 9126, 9127, 9129, 9135, 9142, 9144, 9153, 9153, 9156, 9159, 9168, 9171, 9177, 9178, 9183, 9187, 9193, 9193, 9194, 9202, 9203, 9215, 9216, 9216, 9226, 9227, 9227, 9231, 9238, 9239, 9243, 9243, 9243, 9244, 9252, 9254, 9256, 9269, 9282, 9292, 9300, 9303, 9305, 9312, 9318, 9319, 9342, 9342, 9348, 9350, 9350, 9351, 9355, 9357, 9358, 9359, 9361, 9361, 9361, 9364, 9365, 9367, 9376, 9384, 9392, 9392, 9394, 9396, 9401, 9402, 9403, 9405, 9407, 9408, 9408, 9414, 9417, 9418, 9419, 9423, 9425, 9425, 9430, 9432, 9433, 9439, 9440, 9440, 9442, 9443, 9444, 9444, 9444, 9446, 9447, 9448, 9449, 9451, 9451, 9452, 9452, 9456, 9460, 9468, 9469, 9469, 9470, 9471, 9474, 9485, 9487, 9488, 9496, 9500, 9511, 9512, 9515, 9516, 9516, 9516, 9516, 9527, 9527, 9529, 9529, 9533, 9534, 9536, 9539, 9541, 9542, 9546, 9547, 9547, 9548, 9550, 9551, 9551, 9552, 9553, 9555, 9555, 9555, 9557, 9557, 9561, 9563, 9566, 9567, 9567, 9567, 9568, 9569, 9577, 9578, 9578, 9579, 9580, 9581, 9581, 9582, 9587, 9588, 9590, 9592, 9593, 9594, 9598, 9598, 9599, 9602, 9606, 9610, 9611, 9611, 9613, 9613, 9613, 9617, 9618, 9619, 9619, 9620, 9622, 9622, 9624, 9625, 9626, 9629, 9629, 9630, 9631, 9632, 9633, 9633, 9635, 9636, 9637, 9637, 9639, 9640, 9640, 9642, 9642, 9643, 9643, 9644, 9644, 9649, 9651, 9654, 9655, 9660, 9661, 9663, 9663, 9664, 9664, 9667, 9668, 9668, 9670, 9673, 9674, 9674, 9675, 9676, 9677, 9677, 9678, 9679, 9681, 9682, 9683, 9687, 9688, 9691, 9693, 9696, 9696, 9697, 9700, 9701, 9701, 9703, 9704, 9706, 9706, 9710, 9711, 9712, 9713, 9713, 9715, 9715, 9717, 9719, 9721, 9723, 9723, 9724, 9728, 9728, 9729, 9730, 9730, 9731, 9732, 9732, 9735, 9736, 9736, 9737, 9743, 9744, 9747, 9747, 9748, 9750, 9752, 9755, 9758, 9759, 9759, 9760, 9763, 9767, 9769, 9769, 9769, 9771, 9773, 9777, 9778, 9778, 9779, 9780, 9783, 9785, 9787, 9791, 9793, 9793, 9793, 9795, 9797, 9800, 9800, 9800, 9803, 9803, 9803, 9804, 9806, 9808, 9808, 9808, 9811, 9811, 9811, 9814, 9815, 9815, 9818, 9819, 9820, 9823, 9823, 9824, 9826, 9827, 9830, 9831, 9831, 9832, 9833, 9835, 9836, 9836, 9836, 9837, 9838, 9839, 9839, 9840, 9841, 9841, 9842, 9843, 9844, 9844, 9845, 9845, 9846, 9847, 9848, 9849, 9850, 9850, 9853, 9855, 9855, 9856, 9857, 9861, 9861, 9862, 9865, 9866, 9866, 9867, 9868, 9869, 9870, 9871, 9871, 9872, 9873, 9873, 9873, 9873, 9873, 9874, 9876, 9880, 9880, 9882, 9885, 9886, 9886, 9887, 9888, 9891, 9894, 9895, 9896, 9896, 9897, 9898, 9899, 9899, 9899, 9900, 9900, 9900, 9900, 9901, 9902, 9902, 9903, 9905, 9905, 9908, 9909, 9909, 9911, 9913, 9913, 9913, 9914, 9915, 9917, 9917, 9918, 9921, 9922, 9923, 9924, 9924, 9925, 9928, 9929, 9930, 9930, 9930, 9930, 9930 ...

# %%
fig=plt.figure(figsize=(12,6))
sns.boxplot(provsamateur_2015.Official_Time)

plt.grid()
plt.title('')
plt.ylabel('People')
plt.xlabel('Ki')
plt.show()
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# ## The Elites time for man need to be smaller than 9300 secs, Female 10800

# %% [markdown]
# ## Remove the lines wit '_' values in the rows

# %%
provsamateur_2015.loc[mask.any(axis=1)]
# Out:
#          Bib                        Name  Age M/F  \
# 510     1119  Barrera Munoz, Ruben Dario   41   M
# 1221     311      Hammersmith, Matthew D   27   M
# 2021    2936     Villarreal, Marín G Sr.   30   M
# 2327    4803              Olsen, Lars R.   32   M
# 2787    5643                Curran, Phil   41   M
# ...      ...                         ...  ...  ..
# 26546  26837        Chamberlain, Kira H.   36   F
# 26557  26650             Macon, Laurence   70   M
# 26559  24014                 Wang, Genqi   65   M
# 26561  26176            Teel, Marilyn S.   54   F
# 26578  21042         Corcoran, Heather L   45   F
#
#                                  City State Country Citizen       5K      10K  \
# 510    Tlalnepantla, Estado De Mexico   NaN     MEX     NaN  0:18:40  0:37:32
# 1221                       Greenville    SC     USA     NaN  0:17:49  0:35:28
# 2021                               Df   NaN     MEX     NaN  0:19:55  0:39:49
# 2327                     Copenhagen N   NaN     DEN     NaN        -  0:42:00
# 2787                          Seattle    WA     USA     NaN  0:21:52  0:42:56
# ...                               ...   ...     ...     ...      ...      ...
# 26546                         Orlando    FL     USA     NaN        -  1:14:59
# 26557                     San Antonio    TX     USA     NaN        -  1:19:53
# 26559                         Beijing   NaN     CHN     NaN  0:28:18  1:06:09
# 26561                           Ocala    FL     USA     NaN  0:34:20  1:11:38
# 26578                   Saint Charles    IL     USA     NaN  0:25:09  0:49:38
#
#        ...      25K      30K      35K      40K     Pace Proj Time  \
# 510    ...        -  1:55:27  2:16:08  2:36:13  0:06:18         -
# 1221   ...  1:29:06  1:47:59  2:14:39        -  0:06:36         -
# 2021   ...  1:41:28  2:03:15  2:25:32        -  0:06:47         -
# 2327   ...  1:45:10  2:06:55  2:28:56  2:49:46  0:06:50         -
# 2787   ...  1:45:11  2:07:01  2:29:11        -  0:06:54         -
# ...    ...      ...      ...      ...      ...      ...       ...
# 26546  ...  3:20:43  4:04:46  4:51:33  5:41:12  0:13:52         -
# 26557  ...  3:27:27  4:13:19  4:57:59  5:43:59  0:13:56         -
# 26559  ...  3:16:51  4:03:55  4:50:43        -  0:13:57         -
# 26561  ...  3:21:23  4:07:14  4:54:56        -  0:13:58         -
# 26578  ...  2:22:13  3:03:23        -  5:54:25  0:14:13         -
#
#       Official_Time Overall Gender  Division
# 510            9903     511    493        34
# 1221          10358    1222   1167       957
# 2021          10656    2022   1915      1471
# 2327          10728    2328   2201      1655
# 2787          10841    2788   2632       393
# ...             ...     ...    ...       ...
# 26546         21809   26547  11994      5995
# 26557         21918   26558  14559       120
# 26559         21929   26560  14560       402
# 26561         21957   26562  12001      1204
# 26578         22348   26579  12010      1831
#
# [300 rows x 23 columns]

# %%
to_remove = provsamateur_2015.iloc[mask.any(axis=1)]

# %%
to_remove
# Out:
#          Bib                        Name  Age M/F  \
# 510     1119  Barrera Munoz, Ruben Dario   41   M
# 1221     311      Hammersmith, Matthew D   27   M
# 2021    2936     Villarreal, Marín G Sr.   30   M
# 2327    4803              Olsen, Lars R.   32   M
# 2787    5643                Curran, Phil   41   M
# ...      ...                         ...  ...  ..
# 26546  26837        Chamberlain, Kira H.   36   F
# 26557  26650             Macon, Laurence   70   M
# 26559  24014                 Wang, Genqi   65   M
# 26561  26176            Teel, Marilyn S.   54   F
# 26578  21042         Corcoran, Heather L   45   F
#
#                                  City State Country Citizen       5K      10K  \
# 510    Tlalnepantla, Estado De Mexico   NaN     MEX     NaN  0:18:40  0:37:32
# 1221                       Greenville    SC     USA     NaN  0:17:49  0:35:28
# 2021                               Df   NaN     MEX     NaN  0:19:55  0:39:49
# 2327                     Copenhagen N   NaN     DEN     NaN        -  0:42:00
# 2787                          Seattle    WA     USA     NaN  0:21:52  0:42:56
# ...                               ...   ...     ...     ...      ...      ...
# 26546                         Orlando    FL     USA     NaN        -  1:14:59
# 26557                     San Antonio    TX     USA     NaN        -  1:19:53
# 26559                         Beijing   NaN     CHN     NaN  0:28:18  1:06:09
# 26561                           Ocala    FL     USA     NaN  0:34:20  1:11:38
# 26578                   Saint Charles    IL     USA     NaN  0:25:09  0:49:38
#
#        ...      25K      30K      35K      40K     Pace Proj Time  \
# 510    ...        -  1:55:27  2:16:08  2:36:13  0:06:18         -
# 1221   ...  1:29:06  1:47:59  2:14:39        -  0:06:36         -
# 2021   ...  1:41:28  2:03:15  2:25:32        -  0:06:47         -
# 2327   ...  1:45:10  2:06:55  2:28:56  2:49:46  0:06:50         -
# 2787   ...  1:45:11  2:07:01  2:29:11        -  0:06:54         -
# ...    ...      ...      ...      ...      ...      ...       ...
# 26546  ...  3:20:43  4:04:46  4:51:33  5:41:12  0:13:52         -
# 26557  ...  3:27:27  4:13:19  4:57:59  5:43:59  0:13:56         -
# 26559  ...  3:16:51  4:03:55  4:50:43        -  0:13:57         -
# 26561  ...  3:21:23  4:07:14  4:54:56        -  0:13:58         -
# 26578  ...  2:22:13  3:03:23        -  5:54:25  0:14:13         -
#
#       Official_Time Overall Gender  Division
# 510            9903     511    493        34
# 1221          10358    1222   1167       957
# 2021          10656    2022   1915      1471
# 2327          10728    2328   2201      1655
# 2787          10841    2788   2632       393
# ...             ...     ...    ...       ...
# 26546         21809   26547  11994      5995
# 26557         21918   26558  14559       120
# 26559         21929   26560  14560       402
# 26561         21957   26562  12001      1204
# 26578         22348   26579  12010      1831
#
# [300 rows x 23 columns]

# %%
provsamateur_2015.drop(to_remove.index, axis=0, inplace=True)

# %%
provsamateur_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26593     NaN  0:50:15  1:43:31  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     NaN  0:48:36  1:39:39  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     NaN  0:53:03  1:47:16  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     NaN  0:49:04  1:40:12  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     NaN  0:40:14  1:28:18  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official_Time Overall Gender  Division
# 0      0:04:56         -          7757       1      1         1
# 1      0:04:58         -          7788       2      2         2
# 2      0:04:59         -          7822       3      3         3
# 3      0:05:00         -          7847       4      4         4
# 4      0:05:00         -          7849       5      5         5
# ...        ...       ...           ...     ...    ...       ...
# 26593  0:17:31         -         27536   26594  12015       269
# 26594  0:17:59         -         28290   26595  12016       270
# 26595  0:18:18         -         28773   26596  12017        91
# 26596  0:18:20         -         28837   26597  14580      2055
# 26597  0:18:33         -         29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %% [markdown]
# ## Convert all Km columns to Seconds

# %%
provsamateur_2015['5K'] = seconds(provsamateur_2015['5K'])
provsamateur_2015['10K'] = seconds(provsamateur_2015['10K'])
provsamateur_2015['15K'] = seconds(provsamateur_2015['15K'])
provsamateur_2015['20K'] = seconds(provsamateur_2015['20K'])
provsamateur_2015['Half'] = seconds(provsamateur_2015['Half'])
provsamateur_2015['25K'] = seconds(provsamateur_2015['25K'])
provsamateur_2015['30K'] = seconds(provsamateur_2015['30K'])
provsamateur_2015['35K'] = seconds(provsamateur_2015['35K'])
provsamateur_2015['40K'] = seconds(provsamateur_2015['40K'])
provsamateur_2015['Official Time'] = seconds(provsamateur_2015['Official Time'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Official Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-58057c4c58ea> in <module>
#       8 provsamateur_2015['35K'] = seconds(provsamateur_2015['35K'])
#       9 provsamateur_2015['40K'] = seconds(provsamateur_2015['40K'])
# ---> 10 provsamateur_2015['Official Time'] = seconds(provsamateur_2015['Official Time'])
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Official Time'

# %%
provsamateur_2015['Official_Time'] = seconds(provsamateur_2015['Official_Time'])

# %%
provsamateur_2015

# %% [markdown]
# ## Create a new columns Elites and Amateur:

# %% [markdown]
# Male - Offical time < 9300 - Elites
# Female - Office time < 10800 - Elites
# Rest - NoPro

# %%
#Pros
#provsamateur_2015['M/F']=='M'
#provsamateur_2015['Official Time']<8400
#provsamateur_2015['M/F']=='F'
#provsamateur_2015['Official Time']<9960



#Elites
#provsamateur_2015['M/F']=='M'
#provsamateur_2015['Official Time'].between(8400,9300)
#provsamateur_2015['M/F']=='F'
##provsamateur_2015['Official Time'].between(9960,10800)

#Amateurs
#provsamateur_2015['M/F']=='M'
#provsamateur_2015['Official Time']>9300
#provsamateur_2015['M/F']=='F'
#provsamateur_2015['Official Time']>10800

# %%
conditions = [
    ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official_Time']<8400))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official_Time']<9960)),
    ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official_Time'].between(8400,9300)))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official_Time'].between(9960,10800))),
    ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official_Time']>9300))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official_Time']>10800))]

# %%
values = ['Pro', 'Elite', 'Amateur']

# %%
provsamateur_2015['Category'] = np.select(conditions, values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-1f8fe5d236c5> in <module>
# ----> 1 provsamateur_2015['Category'] = np.select(conditions, values)
#
# NameError: name 'conditions' is not defined

# %%
provsamateur_2015.sample(60)
# Out:
#          Bib                     Name  Age M/F                  City State  \
# 16796  10594               Lesh, Rick   45   M          Indianapolis    IN
# 16466  22439             Cote, France   49   F                Quebec    QC
# 23518  27292        Masiello, Michael   39   M          West Chester    PA
# 6681    9171              Ross, Gayle   49   M             Allentown    PA
# 5924    9140           Dewalt, John D   46   M             Fort Mill    SC
# 17059   7261      Kujawski, Robert J.   53   M             Cutchogue    NY
# 3358    4284         Menon, Abhaya N.   36   M          Falls Church    VA
# 16716  21478             Lehr, Andrea   46   F            Round Rock    TX
# 6321    8447      Rodriguez, Derek A.   49   M            South Hero    VT
# 14113  16114            Weller, Sarah   29   F            Grandville    MI
# 18507  20061   Fossen, Richard F. Jr.   56   M              Minocqua    WI
# 12018  18904        White, Kathleen M   49   F              Portland    OR
# 5916   10048          Cheung, Tat Sin   46   M               Toronto    ON
# 11030  19914       Chapman, Jessica M   37   F            Bennington    VT
# 14739  15428              Wolf, Raffi   36   F         West New York    NJ
# 25561  27089            Tebb, John F.   57   M                Tacoma    WA
# 11210  12135           Boeing, Kory L   34   F            Cincinnati    OH
# 3056    1741              Fort, Brian   23   M             Cleveland    OH
# 19755  12470        Bazdar, Alexandra   21   F            Winchester    VA
# 6116   11405       Stiger, Samantha C   25   F                Lititz    PA
# 8849   13798   Lancaster, Christopher   38   M             Dahlonega    GA
# 224      774             Cox, Stephen   31   M           Tallahassee    FL
# 17043  21959            Murphy, Terry   60   M               Atlanta    GA
# 230      439             Asher, Bobby   29   M                 Bronx    NY
# 3835    5471          Arnold, Brett T   34   M                Morrow    OH
# 20221  23398        Caratozzolo, Beth   51   F          Seneca Falls    NY
# 13137  11907       Gerik, Danielle E.   23   F             Anchorage    AK
# 3426    2334        Schermers, Adrian   27   M               Lacombe    AB
# 26496  26229      Silverman, Jonathan   50   M             Arlington    MA
# 24414  23026        Kitchen, Sheryl M   52   F            St. George    UT
# 16862  22157            Machuca, Lisa   48   F            Pleasanton    CA
# 19520  24836           Baugh, Anita G   57   F               Sartell    MN
# 18526  28997           Buday, John M.   61   M            Essexville    MI
# 15675  20789          Dean, Elizabeth   48   F           Springfield    TN
# 18456  22188        O'Malley, Patrice   50   F             San Bruno    CA
# 22389  27777             Murphy, Bill   54   M              Rockland    MA
# 7412    7264  Kuschnir, Felipe A. Sr.   42   M              Santiago   NaN
# 14017  20260         Faber, Monique D   42   F             Fitchburg    WI
# 8368    8085             Prochko, Tim   42   M               Oakland    MI
# 13398   6616             King, Alex P   43   M              Hoschton    GA
# 20283  22504           Ramsay, John P   60   M        Fredericksburg    TX
# 21954  27604    Farrell, Robert F. II   26   M              Bethesda    MD
# 12690  13465             Lillie, Eric   55   M  Ste Anne De Bellevue    QC
# 8863    6871         Mollen, Burkhard   46   M                 Essen   NaN
# 5655    7697          Lepine, Jocelyn   47   M            Shawinigan    QC
# 6766    9480              Hewitt, Ted   46   M            Burlington    ON
# 17261  18903           Rix, Michael R   60   M           Mississauga    ON
# 21170  26196           Kardok, Meghan   24   F                Boston    MA
# 8791   13016    Hoffmeister, Gayle E.   47   F              Carlisle    PA
# 12591  10026          Bagley, Sean M.   43   M                  Lynn    MA
# 13918  10157        Heckman, Laura D.   27   F               Yardley    PA
# 9470   16965             Pizzi, Becca   35   F               Belmont    MA
# 11754  17659      Moseley, Meredith A   29   F                Dudley    MA
# 20771  28445        Setevage, Kristen   33   F              New York    NY
# 23819  22449               Cruz, Tony   60   M                Denver    CO
# 11470  13945        Langrehr, Mckenna   21   F               Gardner    KS
# 13275  29860     Pandolfi, Michael C.   26   M                Boston    MA
# 19009  26217         Troy, William F.   52   M            Ashburnham    MA
# 15581  18902        Townsend, Susan M   46   F         Traverse City    MI
# 14399  18312            Henly, Ananda   40   F           Minneapolis    MN
#
#       Country Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 16796     USA     NaN  1420  2841  ...   7267   9013  11086  13109  0:08:51
# 16466     CAN     NaN  1660  3276  ...   8101   9745  11413  13083  0:08:48
# 23518     USA     NaN  1983  3929  ...   9790  11759  13754  15696  0:10:34
# 6681      USA     NaN  1397  2761  ...   6989   8421   9856  11305  0:07:35
# 5924      USA     NaN  1364  2713  ...   6743   8127   9578  11065  0:07:28
# 17059     USA     NaN  1422  2880  ...   8406  10086  11690  13251  0:08:53
# 3358      USA     IND  1297  2561  ...   6380   7697   9015  10429  0:07:01
# 16716     USA     NaN  1614  3247  ...   8170   9845  11520  13151  0:08:50
# 6321      USA     NaN  1363  2743  ...   6905   8335   9792  11213  0:07:32
# 14113     USA     NaN  1615  3177  ...   7889   9480  11081  12662  0:08:29
# 18507     USA     NaN  1648  3182  ...   8106   9849  11746  13567  0:09:06
# 12018     USA     NaN  1500  2957  ...   7429   9018  10647  12252  0:08:14
# 5916      CAN     NaN  1395  2738  ...   6815   8224   9693  11116  0:07:28
# 11030     USA     NaN  1524  3002  ...   7465   8980  10528  12078  0:08:08
# 14739     USA     GER  1498  3008  ...   7695   9382  11101  12749  0:08:34
# 25561     USA     NaN  2142  4293  ...  10990  13302  15664  17975  0:12:06
# 11210     USA     NaN  1549  3113  ...   7696   9284  10822  12193  0:08:09
# 3056      USA     NaN  1315  2592  ...   6432   7730   9026  10316  0:06:57
# 19755     USA     NaN  1487  3288  ...   8411  10258  12127  13949  0:09:22
# 6116      USA     NaN  1417  2824  ...   7034   8446   9862  11196  0:07:30
# 8849      USA     NaN  1504  2950  ...   7296   8779  10251  11739  0:07:52
# 224       USA     NaN  1207  2383  ...   5741   6840   7946   9033  0:06:04
# 17043     USA     NaN  1576  3155  ...   7912   9613  11444  13146  0:08:52
# 230       USA     NaN  1125  2265  ...   5663   6779   7867   9013  0:06:04
# 3835      USA     NaN  1303  2601  ...   6438   7739   9061  10499  0:07:07
# 20221     USA     NaN  1699  3365  ...   8489  10288  12189  14080  0:09:28
# 13137     USA     NaN  1452  2876  ...   7142   8657  10370  12285  0:08:22
# 3426      CAN     NaN  1222  2412  ...   6205   7487   8892  10466  0:07:02
# 26496     USA     NaN  2080  4235  ...  11918  14813  17661  20373  0:13:41
# 24414     USA     NaN  1635  3437  ...   9571  11960  14211  16408  0:11:04
# 16862     USA     NaN  1556  3107  ...   7953   9654  11426  13158  0:08:51
# 19520     USA     NaN  1574  3155  ...   8207  10041  11941  13817  0:09:19
# 18526     USA     NaN  1674  3287  ...   8161   9885  11704  13492  0:09:06
# 15675     USA     NaN  1572  3117  ...   7958   9608  11304  12949  0:08:42
# 18456     USA     NaN  1591  3149  ...   8141   9916  11831  13550  0:09:05
# 22389     USA     NaN  1795  3441  ...   8565  10558  12669  14922  0:10:05
# 7412      CHI     NaN  1305  2621  ...   6621   8125   9728  11335  0:07:42
# 14017     USA     NaN  1559  3127  ...   7858   9440  11053  12638  0:08:28
# 8368      USA     NaN  1450  2833  ...   7097   8590  10099  11677  0:07:49
# 13398     USA     NaN  1313  2692  ...   6982   8583  10352  12356  0:08:24
# 20283     USA     NaN  1687  3359  ...   8480  10288  12159  14077  0:09:29
# 21954     USA     NaN  1806  3429  ...   8534  10353  12433  14702  0:09:57
# 12690     CAN     NaN  1448  2884  ...   7324   8930  10653  12330  0:08:19
# 8863      GER     NaN  1385  2831  ...   7208   8694  10214  11702  0:07:53
# 5655      CAN     NaN  1361  2671  ...   6669   8099   9605  11042  0:07:25
# 6766      CAN     NaN  1416  2774  ...   6933   8392   9866  11307  0:07:36
# 17261     CAN     NaN  1526  3041  ...   7737   9453  11306  13161  0:08:54
# 21170     USA     NaN  1802  3571  ...   9025  10875  12687  14506  0:09:43
# 8791      USA     NaN  1401  2809  ...   7141   8641  10200  11705  0:07:52
# 12591     USA     NaN  1453  2940  ...   7533   9094  10701  12305  0:08:18
# 13918     USA     NaN  1483  2959  ...   7468   9071  10745  12581  0:08:28
# 9470      USA     NaN  1473  2929  ...   7352   8855  10370  11847  0:07:57
# 11754     USA     NaN  1508  2995  ...   7459   9016  10647  12207  0:08:12
# 20771     USA     NaN  1824  3520  ...   8720  10543  12440  14302  0:09:36
# 23819     USA     NaN  1721  3424  ...   8961  11194  13519  15896  0:10:42
# 11470     USA     NaN  1479  2973  ...   7507   9068  10664  12190  0:08:10
# 13275     USA     NaN  1698  3139  ...   7578   9175  10785  12463  0:08:23
# 19009     USA     NaN  1807  3504  ...   8516  10259  12018  13733  0:09:11
# 15581     USA     NaN  1511  2989  ...   7723   9419  11181  12889  0:08:41
# 14399     USA     NaN  1511  2995  ...   7615   9341  11038  12694  0:08:31
#
#        Proj Time  Official_Time Overall Gender  Division
# 16796          -          13898   16797  10478      1974
# 16466          -          13829   16467   6133       753
# 23518          -          16602   23519  13242      4586
# 6681           -          11926    6682   5728       876
# 5924           -          11736    5925   5201       702
# 17059          -          13949   17060  10580      1561
# 3358           -          11021    3359   3151      2256
# 16716          -          13883   16717   6270       785
# 6321           -          11840    6322   5487       797
# 14113          -          13332   14114   4670      3233
# 18507          -          14295   18508  11147      1081
# 12018          -          12943   12019   3465       249
# 5916           -          11734    5917   5196       701
# 11030          -          12770   11031   2895      2245
# 14739          -          13460   14740   5061      3394
# 25561          -          19021   25562  14128      1442
# 11210          -          12799   11211   2990      2305
# 3056           -          10927    3057   2877      2092
# 19755          -          14712   19756   8102      4361
# 6116           -          11788    6117    781       673
# 8849           -          12374    8850   7045      3418
# 224            -           9529     225    212       196
# 17043          -          13946   17044  10571       341
# 230            -           9541     231    218       202
# 3835           -          11173    3836   3563      2465
# 20221          -          14885   20222   8385       774
# 13137          -          13150   13138   4098      2970
# 3426           -          11046    3427   3211      2291
# 26496          -          21507   26497  14533      2052
# 24414          -          17399   24415  10770      1106
# 16862          -          13912   16863   6362       805
# 19520          -          14631   19521   7972       227
# 18526          -          14301   18527  11157       441
# 15675          -          13661   15676   5642       623
# 18456          -          14281   18457   7336       576
# 22389          -          15860   22390  12731      1822
# 7412           -          12096    7413   6202      1198
# 14017          -          13312   14018   4618       750
# 8368           -          12279    8369   6779      1277
# 13398          -          13199   13399   9149      1529
# 20283          -          14907   20284  11857       572
# 21954          -          15652   21955  12540      4392
# 12690          -          13070   12691   8845       595
# 8863           -          12378    8864   7053      1313
# 5655           -          11664    5656   5008       632
# 6766           -          11943    6767   5790       893
# 17261          -          13994   17262  10653       359
# 21170          -          15266   21171   8980      4620
# 8791           -          12364    8792   1782        85
# 12591          -          13049   12592   8802      1499
# 13918          -          13294   13919   4553      3190
# 9470           -          12491    9471   2087      1676
# 11754          -          12895   11755   3309      2506
# 20771          -          15096   20772   8736      4525
# 23819          -          16814   23820  13379       790
# 11470          -          12844   11471   3144      2403
# 13275          -          13175   13276   9099      3749
# 19009          -          14444   19010  11368      1663
# 15581          -          13642   15582   5589       611
# 14399          -          13388   14400   4850       813
#
# [60 rows x 23 columns]

# %% [markdown]
# ## Calculate the Avarage Per Kilometer of the Pros, Elites and the Amateurs

# %%
provsamateur_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 0         NaN   883  1783  ...   4567   5520   6479   7359  0:04:56
# 1         NaN   883  1783  ...   4567   5519   6479   7362  0:04:58
# 2         NaN   883  1783  ...   4567   5520   6479   7381  0:04:59
# 3         NaN   883  1784  ...   4567   5520   6483   7427  0:05:00
# 4         NaN   883  1784  ...   4567   5520   6479   7407  0:05:00
# ...       ...   ...   ...  ...    ...    ...    ...    ...      ...
# 26593     NaN  3015  6211  ...  15953  19184  22639  26014  0:17:31
# 26594     NaN  2916  5979  ...  16364  19918  23336  26779  0:17:59
# 26595     NaN  3183  6436  ...  16431  20336  23931  27378  0:18:18
# 26596     NaN  2944  6012  ...  16160  19871  23615  27338  0:18:20
# 26597     NaN  2414  5298  ...  16566  20624  24691  27688  0:18:33
#
#        Proj Time  Official_Time Overall Gender  Division
# 0              -           7757       1      1         1
# 1              -           7788       2      2         2
# 2              -           7822       3      3         3
# 3              -           7847       4      4         4
# 4              -           7849       5      5         5
# ...          ...            ...     ...    ...       ...
# 26593          -          27536   26594  12015       269
# 26594          -          28290   26595  12016       270
# 26595          -          28773   26596  12017        91
# 26596          -          28837   26597  14580      2055
# 26597          -          29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %%
provsamateur_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 0         NaN   883  1783  ...   4567   5520   6479   7359  0:04:56
# 1         NaN   883  1783  ...   4567   5519   6479   7362  0:04:58
# 2         NaN   883  1783  ...   4567   5520   6479   7381  0:04:59
# 3         NaN   883  1784  ...   4567   5520   6483   7427  0:05:00
# 4         NaN   883  1784  ...   4567   5520   6479   7407  0:05:00
# ...       ...   ...   ...  ...    ...    ...    ...    ...      ...
# 26593     NaN  3015  6211  ...  15953  19184  22639  26014  0:17:31
# 26594     NaN  2916  5979  ...  16364  19918  23336  26779  0:17:59
# 26595     NaN  3183  6436  ...  16431  20336  23931  27378  0:18:18
# 26596     NaN  2944  6012  ...  16160  19871  23615  27338  0:18:20
# 26597     NaN  2414  5298  ...  16566  20624  24691  27688  0:18:33
#
#        Proj Time  Official_Time Overall Gender  Division
# 0              -           7757       1      1         1
# 1              -           7788       2      2         2
# 2              -           7822       3      3         3
# 3              -           7847       4      4         4
# 4              -           7849       5      5         5
# ...          ...            ...     ...    ...       ...
# 26593          -          27536   26594  12015       269
# 26594          -          28290   26595  12016       270
# 26595          -          28773   26596  12017        91
# 26596          -          28837   26597  14580      2055
# 26597          -          29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %%
provsamateur_2015_avg = provsamateur_2015.groupby('Category')[['5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official_Time']].agg('mean').round()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-09fb7fe51d5a> in <module>
# ----> 1 provsamateur_2015_avg = provsamateur_2015.groupby('Category')[['5K', '10K', '15K', '20K', 'Half', '25K', '30K', '35K','40K', 'Official_Time']].agg('mean').round()
#
# ~\miniconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6712         axis = self._get_axis_number(axis)
#    6713
# -> 6714         return DataFrameGroupBy(
#    6715             obj=self,
#    6716             keys=by,
#
# ~\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~\miniconda3\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809                 in_axis, name, level, gpr = False, None, gpr, None
#     810             else:
# --> 811                 raise KeyError(gpr)
#     812         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813             # Add key to exclusions
#
# KeyError: 'Category'

# %%
provsamateur_2015_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-e3a59242c4f7> in <module>
# ----> 1 provsamateur_2015_avg
#
# NameError: name 'provsamateur_2015_avg' is not defined

# %%
provsamateur_2015_avg.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-4c9040323215> in <module>
# ----> 1 provsamateur_2015_avg.reset_index()
#
# NameError: name 'provsamateur_2015_avg' is not defined

# %%
provsamateur_2015_avg = provsamateur_2015_avg.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-140-ec75d3d41718> in <module>
# ----> 1 provsamateur_2015_avg = provsamateur_2015_avg.reset_index()
#
# NameError: name 'provsamateur_2015_avg' is not defined

# %%
provsamateur_2015_avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-e3a59242c4f7> in <module>
# ----> 1 provsamateur_2015_avg
#
# NameError: name 'provsamateur_2015_avg' is not defined

# %%
def seconds5K_cat(j):
    """ 
    This function will take the time each 5 kilometers and calculate the pace per kilometter
    Input = DataFrame with time each 5 km in seconds
    Output: DataFrame pace per kilomter.
    
    """
    seconds_to_minute  = 60
    df = j.copy()
    df = df[['Category','5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', 'Official_Time']]
    df = df.rename(columns={'Official_Time': '42K'})
    
    for i,k in enumerate(df.columns): 
        if i == 0:
            pass
        elif i==1:
            df[5] = ((df[k])/5)
        elif i == 2:
            df[10] = ((df[k]-df['5K'])/5)
        elif i == 3:
            df[15] = ((df[k]-df['10K'])/5)
        elif i == 4:
            df[20] = ((df[k]-df['15K'])/5)
        elif i == 5:
            df[25] = ((df[k]-df['20K'])/5)
        elif i == 6:
            df[30] = ((df[k]-df['25K'])/5)
        elif i == 7:
            df[35] = ((df[k]-df['30K'])/5)
        elif i == 8:
            df[40] = ((df[k]-df['35K'])/5)
        elif i == 9:
            df[42] = ((df[k]-df['40K'])/2)
    df = df.drop(['5K', '10K', '15K', '20K', '25K', '30K', '35K','40K', '42K'], axis=1)
    return df

# %%
provsamateur_2015_avg_sec = seconds5K_cat(provsamateur_2015_avg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-fd3134895790> in <module>
# ----> 1 provsamateur_2015_avg_sec = seconds5K_cat(provsamateur_2015_avg)
#
# NameError: name 'provsamateur_2015_avg' is not defined

# %%
provsamateur_2015_avg_melt = provsamateur_2015_avg_sec.melt(id_vars=['Category'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-144-01662814f7ff> in <module>
# ----> 1 provsamateur_2015_avg_melt = provsamateur_2015_avg_sec.melt(id_vars=['Category'])
#
# NameError: name 'provsamateur_2015_avg_sec' is not defined

# %%
provsamateur_2015_avg_melt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-5720b6f1bc68> in <module>
# ----> 1 provsamateur_2015_avg_melt
#
# NameError: name 'provsamateur_2015_avg_melt' is not defined

# %%
fig=plt.figure(figsize=(12,6))
strategy_winners = sns.barplot(data=provsamateur_2015_avg_melt, y='value', x='variable', hue='Category')

a = strategy_winners.get_yticks().tolist()
a[1]= '3.40'
a[2]= '4.00'
a[3]= '4.33'
a[4]='4.66'
a[5]='5.00'
a[6]='5.33'
a[7]='5,66'

strategy_winners.set_yticklabels(a);
plt.grid()
plt.title('Amateurs, Elites, Pros')
plt.ylabel('Time')
plt.xlabel('Kilometers')

plt.savefig('pro_elite_amateur', dpi = 300);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-518f0a97b279> in <module>
#       1 fig=plt.figure(figsize=(12,6))
# ----> 2 strategy_winners = sns.barplot(data=provsamateur_2015_avg_melt, y='value', x='variable', hue='Category')
#       3
#       4 a = strategy_winners.get_yticks().tolist()
#       5 a[1]= '3.40'
#
# NameError: name 'provsamateur_2015_avg_melt' is not defined

# %%
fig = px.line(provsamateur_2015_avg_melt, y=provsamateur_2015_avg_melt['value'], x=provsamateur_2015_avg_melt['variable'], color='Category')

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-c546af1ae86d> in <module>
# ----> 1 fig = px.line(provsamateur_2015_avg_melt, y=provsamateur_2015_avg_melt['value'], x=provsamateur_2015_avg_melt['variable'], color='Category')
#       2
#       3 fig.show()
#
# NameError: name 'provsamateur_2015_avg_melt' is not defined

# %% [markdown]
# ## Create Category per per age !

# %%
boston_2015
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen       5K      10K  ...      25K      30K      35K      40K  \
# 0         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:02:39
# 1         NaN  0:14:43  0:29:43  ...  1:16:07  1:31:59  1:47:59  2:02:42
# 2         NaN  0:14:43  0:29:43  ...  1:16:07  1:32:00  1:47:59  2:03:01
# 3         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:48:03  2:03:47
# 4         NaN  0:14:43  0:29:44  ...  1:16:07  1:32:00  1:47:59  2:03:27
# ...       ...      ...      ...  ...      ...      ...      ...      ...
# 26593     NaN  0:50:15  1:43:31  ...  4:25:53  5:19:44  6:17:19  7:13:34
# 26594     NaN  0:48:36  1:39:39  ...  4:32:44  5:31:58  6:28:56  7:26:19
# 26595     NaN  0:53:03  1:47:16  ...  4:33:51  5:38:56  6:38:51  7:36:18
# 26596     NaN  0:49:04  1:40:12  ...  4:29:20  5:31:11  6:33:35  7:35:38
# 26597     NaN  0:40:14  1:28:18  ...  4:36:06  5:43:44  6:51:31  7:41:28
#
#           Pace Proj Time Official Time Overall Gender Division
# 0      0:04:56         -       2:09:17       1      1        1
# 1      0:04:58         -       2:09:48       2      2        2
# 2      0:04:59         -       2:10:22       3      3        3
# 3      0:05:00         -       2:10:47       4      4        4
# 4      0:05:00         -       2:10:49       5      5        5
# ...        ...       ...           ...     ...    ...      ...
# 26593  0:17:31         -       7:38:56   26594  12015      269
# 26594  0:17:59         -       7:51:30   26595  12016      270
# 26595  0:18:18         -       7:59:33   26596  12017       91
# 26596  0:18:20         -       8:00:37   26597  14580     2055
# 26597  0:18:33         -       8:06:01   26598  14581      898
#
# [26598 rows x 23 columns]

# %%
fig=plt.figure(figsize=(24,12))
age_2015 = sns.histplot(data=boston_2015, x='Age')
plt.grid()
plt.title('Age')
plt.ylabel('Number of runners')
plt.xlabel('Age')
plt.show()

# %%
fig=plt.figure(figsize=(24,12))
age =sns.distplot(boston_2015['Age'], kde=True, kde_kws={"color": "g", "alpha":0.3, "linewidth": 5, "shade":True });
plt.grid();
plt.yscale('linear');
type(age)
vals = age.get_yticks()
age.set_yticklabels(['{:,.2%}'.format(x) for x in vals]);
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# <ipython-input-150-c2b259054782>:7: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
fig=plt.figure(figsize=(24,12))
age =sns.distplot(boston_2015['Age'], kde=True, kde_kws={"color": "g", "alpha":0.3, "linewidth": 5, "shade":True });
plt.grid();
plt.yscale('linear');
type(age)
vals = age.get_yticks()
age.set_yticklabels(['{:,.2%}'.format(x) for x in vals]);
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# <ipython-input-151-c2b259054782>:7: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ## Conditions and Values

# %% [markdown]
# ```Python
#
# conditions = [
#     ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official Time']<8400))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official Time']<9960)),
#     ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official Time'].between(8400,9300)))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official Time'].between(9960,10800))),
#     ((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official Time']>9300))|((provsamateur_2015['M/F']=='F')&(provsamateur_2015['Official Time']>10800))]
#
# ```

# %%
#((provsamateur_2015['M/F']=='M')&(provsamateur_2015['Official Time'].between(8400,9300)

# %%
boston_2015_age = provsamateur_2015.copy()

# %%
boston_2015_age
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 0         NaN   883  1783  ...   4567   5520   6479   7359  0:04:56
# 1         NaN   883  1783  ...   4567   5519   6479   7362  0:04:58
# 2         NaN   883  1783  ...   4567   5520   6479   7381  0:04:59
# 3         NaN   883  1784  ...   4567   5520   6483   7427  0:05:00
# 4         NaN   883  1784  ...   4567   5520   6479   7407  0:05:00
# ...       ...   ...   ...  ...    ...    ...    ...    ...      ...
# 26593     NaN  3015  6211  ...  15953  19184  22639  26014  0:17:31
# 26594     NaN  2916  5979  ...  16364  19918  23336  26779  0:17:59
# 26595     NaN  3183  6436  ...  16431  20336  23931  27378  0:18:18
# 26596     NaN  2944  6012  ...  16160  19871  23615  27338  0:18:20
# 26597     NaN  2414  5298  ...  16566  20624  24691  27688  0:18:33
#
#        Proj Time  Official_Time Overall Gender  Division
# 0              -           7757       1      1         1
# 1              -           7788       2      2         2
# 2              -           7822       3      3         3
# 3              -           7847       4      4         4
# 4              -           7849       5      5         5
# ...          ...            ...     ...    ...       ...
# 26593          -          27536   26594  12015       269
# 26594          -          28290   26595  12016       270
# 26595          -          28773   26596  12017        91
# 26596          -          28837   26597  14580      2055
# 26597          -          29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %%
conditions_age = [(boston_2015_age['Age'].between(0,20)),
                  (boston_2015_age['Age'].between(20,30)),
                  (boston_2015_age['Age'].between(30,40)),
                  (boston_2015_age['Age'].between(40,50)),
                  (boston_2015_age['Age'].between(50,60)),
                  (boston_2015_age['Age'].between(60,70)),
                  (boston_2015_age['Age'].between(70,80)),]

# %%
conditions_age = [(boston_2015_age['Age'].between(0,20)),
                  (boston_2015_age['Age'].between(20,30)),
                  (boston_2015_age['Age'].between(30,40)),
                  (boston_2015_age['Age'].between(40,50)),
                  (boston_2015_age['Age'].between(50,60)),
                  (boston_2015_age['Age'].between(60,70)),
                  (boston_2015_age['Age'].between(70,80))]

# %%
values = ['Teens', '20s', '30s', '40s', '50s', '60s', '70s']

# %%
boston_2015_age['Age_cat'] = np.select(conditions_age, values_age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-3446082609c7> in <module>
# ----> 1 boston_2015_age['Age_cat'] = np.select(conditions_age, values_age)
#
# NameError: name 'values_age' is not defined

# %%
boston_2015_age

# %%
boston_2015_age['Official_Time'] = seconds(boston_2015_age['Official_Time'])

# %%
boston_2015_age.Age_cat.unique()

# %%
boston_2015_age[boston_2015_age['Age_cat']==0]

# %%
ordered=['Teens', '20s', '30s', '40s', '50s', '60s', '70s']

# %%
fig=plt.figure(figsize=(18,8))

age_time =sns.scatterplot(data=boston_2015_age, x=boston_2015_age['Age'], y=boston_2015_age['Official_Time'], hue='Category')
a = age_time.get_yticks().tolist()
a[1]= '2:46'
a[2]= '4:10'
a[3]= '5:33'
a[4]='6:56'
a[5]='8:33'
age_time.set_yticklabels(a);
plt.xlabel("Age", fontsize=16)
plt.ylabel("Official Time (hor)",fontsize=16)
plt.title("Official Time for Age",fontsize=16)
plt.savefig('Time_Age', dpi = 300);
plt.show()

# %%
boston_2015_age['M/F']
# Out:
# 0        M
# 1        M
# 2        M
# 3        M
# 4        M
#         ..
# 26593    F
# 26594    F
# 26595    F
# 26596    M
# 26597    M
# Name: M/F, Length: 26298, dtype: object

# %%
fig=plt.figure(figsize=(13,8))
sns.set_theme()

order=['Teens', '20s', '30s', '40s', '50s', '60s', '70s']
age_gender = sns.countplot('Age_cat', data=boston_2015_age, palette='pastel', order=order, hue='M/F', kde_kws={"color": "g", "alpha":0.3, "linewidth": 5, "shade":True });
for p in age_gender.patches:
    age_gender.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
age_gender.set_title('Runners age and gender')
age_gender.set(xlabel='Age by category', ylabel='Runners & Gender')
plt.savefig('runners_2015_age_gender.png', dpi = 300);
plt.grid();
plt.yscale('linear');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-81955c4c87cb> in <module>
# ----> 1 fig=plt.figure(figsize=(13,8))
#       2 sns.set_theme()
#       3
#       4 order=['Teens', '20s', '30s', '40s', '50s', '60s', '70s']
#       5 age_gender = sns.countplot('Age_cat', data=boston_2015_age, palette='pastel', order=order, hue='M/F', kde_kws={"color": "g", "alpha":0.3, "linewidth": 5, "shade":True });
#
# NameError: name 'plt' is not defined

# %%
g = sns.boxplot(boston_2015['M/F'], boston_2015['Age'], palette="coolwarm")
g.figure.set_size_inches(13,8)
g.set(xlabel='Age', ylabel='Gender')
for p in g.patches:
    g.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
g.set_title("Distribution per age and gender group")
plt.savefig('BoxPlot_2015_age_gender.png', dpi = 300);
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
s = boston_2015.groupby('Country').count()['City'].sort_values(ascending=False).head(21)
g = sns.barplot(s.index, s, palette='rainbow')
g.figure.set_size_inches(13,8)
g.set_title("Most popular Country")
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Most popular Country')

# %%
s = boston_2015.groupby('Country').count()['City'].sort_values(ascending=False).head(20)[1:]
g = sns.barplot(s.index, s, palette='rainbow')
g.figure.set_size_inches(13,8)
g.set_title("Most popular Country")
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0.5, 1.0, 'Most popular Country')

# %%
s = boston_2015.groupby('Country').count()['City'].sort_values(ascending=False).head(21)[2:]
g = sns.barplot(s.index, s, palette='rainbow')
g.figure.set_size_inches(13,8)
g.set_title("Most popular country")
g.set(xlabel='Country', ylabel='Number of participants')
plt.savefig('runners_2015_age_gender.png', dpi = 300);
plt.grid();
plt.savefig('Barplot by Country.png', dpi = 300);
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.heatmap(boston_2015_age.corr(), cmap='PiYG', vmin=-1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(boston_2015_age[['Gender', 'Official_Time']].corr() , cmap='PiYG', vmin=-1)
# Out:
# <AxesSubplot:>

# %%
boston_2015_age
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 0         NaN   883  1783  ...   4567   5520   6479   7359  0:04:56
# 1         NaN   883  1783  ...   4567   5519   6479   7362  0:04:58
# 2         NaN   883  1783  ...   4567   5520   6479   7381  0:04:59
# 3         NaN   883  1784  ...   4567   5520   6483   7427  0:05:00
# 4         NaN   883  1784  ...   4567   5520   6479   7407  0:05:00
# ...       ...   ...   ...  ...    ...    ...    ...    ...      ...
# 26593     NaN  3015  6211  ...  15953  19184  22639  26014  0:17:31
# 26594     NaN  2916  5979  ...  16364  19918  23336  26779  0:17:59
# 26595     NaN  3183  6436  ...  16431  20336  23931  27378  0:18:18
# 26596     NaN  2944  6012  ...  16160  19871  23615  27338  0:18:20
# 26597     NaN  2414  5298  ...  16566  20624  24691  27688  0:18:33
#
#        Proj Time  Official_Time Overall Gender  Division
# 0              -           7757       1      1         1
# 1              -           7788       2      2         2
# 2              -           7822       3      3         3
# 3              -           7847       4      4         4
# 4              -           7849       5      5         5
# ...          ...            ...     ...    ...       ...
# 26593          -          27536   26594  12015       269
# 26594          -          28290   26595  12016       270
# 26595          -          28773   26596  12017        91
# 26596          -          28837   26597  14580      2055
# 26597          -          29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %%
boston_2015_age.loc[boston_2015_age['Official_Time']<7788]
# Out:
#   Bib            Name  Age M/F  City State Country Citizen   5K   10K  ...  \
# 0   3  Desisa, Lelisa   25   M  Ambo   NaN     ETH     NaN  883  1783  ...
#
#     25K   30K   35K   40K     Pace  Proj Time  Official_Time Overall Gender  \
# 0  4567  5520  6479  7359  0:04:56          -           7757       1      1
#
#    Division
# 0         1
#
# [1 rows x 23 columns]

# %%
boston_2015_age.groupby('Country')['Official_Time'].mean().sort_values(ascending=False)
# Out:
# Country
# UGA    18354.000000
# PHI    17352.000000
# INA    17048.666667
# AHO    16016.000000
# TRI    15865.333333
#            ...
# CYP    10212.000000
# BLR     8963.000000
# KEN     8527.777778
# ETH     8373.428571
# UKR     8032.000000
# Name: Official_Time, Length: 78, dtype: float64

# %%
boston_2015_age
# Out:
#          Bib                   Name  Age M/F           City State Country  \
# 0          3         Desisa, Lelisa   25   M           Ambo   NaN     ETH
# 1          4  Tsegay, Yemane Adhane   30   M    Addis Ababa   NaN     ETH
# 2          8         Chebet, Wilson   29   M       Marakwet   NaN     KEN
# 3         11       Kipyego, Bernard   28   M        Eldoret   NaN     KEN
# 4         10          Korir, Wesley   32   M         Kitale   NaN     KEN
# ...      ...                    ...  ...  ..            ...   ...     ...
# 26593  25656  Prescott, Francine J.   64   F  Boynton Beach    FL     USA
# 26594  31359    Emerson, Annette C.   61   F       Old Town    ME     USA
# 26595  25559          Cerveny, Nona   66   F     Scottsdale    AZ     USA
# 26596  29396    Buccilli, Alfred P.   53   M      Lynnfield    MA     USA
# 26597  25651        Reilly, William   62   M     Kew Garden    NY     USA
#
#       Citizen    5K   10K  ...    25K    30K    35K    40K     Pace  \
# 0         NaN   883  1783  ...   4567   5520   6479   7359  0:04:56
# 1         NaN   883  1783  ...   4567   5519   6479   7362  0:04:58
# 2         NaN   883  1783  ...   4567   5520   6479   7381  0:04:59
# 3         NaN   883  1784  ...   4567   5520   6483   7427  0:05:00
# 4         NaN   883  1784  ...   4567   5520   6479   7407  0:05:00
# ...       ...   ...   ...  ...    ...    ...    ...    ...      ...
# 26593     NaN  3015  6211  ...  15953  19184  22639  26014  0:17:31
# 26594     NaN  2916  5979  ...  16364  19918  23336  26779  0:17:59
# 26595     NaN  3183  6436  ...  16431  20336  23931  27378  0:18:18
# 26596     NaN  2944  6012  ...  16160  19871  23615  27338  0:18:20
# 26597     NaN  2414  5298  ...  16566  20624  24691  27688  0:18:33
#
#        Proj Time  Official_Time Overall Gender  Division
# 0              -           7757       1      1         1
# 1              -           7788       2      2         2
# 2              -           7822       3      3         3
# 3              -           7847       4      4         4
# 4              -           7849       5      5         5
# ...          ...            ...     ...    ...       ...
# 26593          -          27536   26594  12015       269
# 26594          -          28290   26595  12016       270
# 26595          -          28773   26596  12017        91
# 26596          -          28837   26597  14580      2055
# 26597          -          29161   26598  14581       898
#
# [26298 rows x 23 columns]

# %%
s = boston_2015_age.groupby('Country')['Official_Time'].mean().sort_values(ascending=True).head(21)
g = sns.barplot(s.index, s, palette='colorblind')
a = g.get_yticks().tolist()
a[1]= '2:46'
a[2]= '4:10'
a[3]= '5:33'
a[4]='6:56'
a[5]='8:33'
a[6]='8:56'
g.set_yticklabels(a);
g.figure.set_size_inches(13,8)
g.set_title("Most popular country")
g.set(xlabel='Country', ylabel='Number of participants')
plt.savefig('runners_2015_age_gender.png', dpi = 300);
plt.grid();
plt.savefig('Barplot by Country.png', dpi = 300);
# Out:
# C:\Users\israe\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# <ipython-input-181-50dd74679af4>:10: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator

# %%
country_time = sns.catplot(data=boston_2015_age, x=boston_2015_age['Official_Time'], y=boston_2015_age['Country'], kind='violin');
g.set_title("Most faster country");
g.set(xlabel='Number of participants', ylabel='Country');

# %%
g.figure.set_size_inches(12,8)
country_time = sns.catplot(data=boston_2015_age, x='Country', y='Official_Time');
country_time.set_xticklabels(rotation=90)
